# %%
import pandas as pd
import json
import os

# %% [markdown]
# # Class for Restructuring

# %% [markdown]
# #### Note for Restructuring
#
# There are 7 columns.
#
# | Column         | Description                         |
# |----------------|-------------------------------------|
# | id             | Unique identifier                   |
# | title          | Title of research                   |
# | category       | tuple (code, subject name, abbrev)  |
# | authors        | List of authors                     |
# | year           | Year of publication                 |
# | abstracts      | Abstract text                       |
# | references     | List of references (id of research) |

# %%
class utils:
    def id_apply(x):
        return x["prism:url"].split("/")[-1]
    
    def title_apply(x):
        if "dc:title" not in x or x["dc:title"] == None:
            return None
        return x["dc:title"]
    
    def author_apply(x):
        name_list = []
        for author in x["author"]:
            name_to_append = ""
            if "ce:given-name" in author:
                name_to_append = f"{author['ce:given-name']} {author['ce:surname']}"
            else: 
                name_to_append = author["ce:indexed-name"]
            name_list.append(name_to_append)
        return name_list
    
    def abstracts_apply(x):
        if "dc:description" not in x or x["dc:description"] == None:
            return None
        return x["dc:description"]
    
    def reference_apply(x):
        if x["bibrecord"] == None or x["bibrecord"]["tail"] == None or x["bibrecord"]["tail"]["bibliography"] == None or x["bibrecord"]["tail"]["bibliography"]["reference"] == None:
            return None
        reference_list = []
        temp = x["bibrecord"]["tail"]["bibliography"]["reference"]
        if type(temp) != type([]):
            temp = [temp]
        for ref in temp:
            if "ref-info" not in ref or "refd-itemidlist" not in ref["ref-info"]:
                continue
            if type(ref["ref-info"]["refd-itemidlist"]["itemid"]) == type([]):
                for j in ref["ref-info"]["refd-itemidlist"]["itemid"]:
                    if "@idtype" in j and j["@idtype"] == "SGR":
                        reference_list.append(j["$"])
            else:
                if "@idtype" in ref["ref-info"]["refd-itemidlist"]["itemid"] and ref["ref-info"]["refd-itemidlist"]["itemid"]["@idtype"] == "SGR":
                    reference_list.append(ref["ref-info"]["refd-itemidlist"]["itemid"]["$"])
        if len(reference_list) == 0:
            return None
        return reference_list
    
    def subject_apply(x):
        subject_list = []
        for subject in x["subject-area"]:
            name = subject["$"]
            code = subject["@code"]
            abbrev = subject["@abbrev"]
            subject_list.append((name, code, abbrev))
        return subject_list

# %%
class PrepareData:
    def __init__(self) -> None:
        self.data = None
        self.data_dir = "./data"
    
    def load_data(self):
        dfs = []
        dir_list = os.listdir("./data")
        cnt = 0
        for i in dir_list:
            if i == ".DS_Store":
                continue

            # Handle too many data
            # if not (i == "2018" or i == "2019"):
            #     continue
            
            sub_dir = os.path.join("./data", i)
            files = os.listdir(sub_dir)
            for f in files:
                if f == ".DS_Store":
                    continue

                file_path = os.path.join(sub_dir, f)
                with open(file_path, "r") as file:
                    json_data = json.load(file)

                row = {key: value for key, value in json_data["abstracts-retrieval-response"].items()}
                row["year"] = int(i)
                dfs.append(pd.DataFrame([row]))
                cnt += 1

        df = pd.concat(dfs, ignore_index=True)
        print("Total data: ", cnt)
        self.data = df

    def save_data(self):
        self.data.to_csv("data.csv", index=False)

    def restructure(self):
        df = self.data.copy()
        
        df["id"] = df["coredata"].apply(utils.id_apply)
        df["title"] = df["coredata"].apply(utils.title_apply)
        df["authors"] = df["authors"].apply(utils.author_apply)
        df["abstracts"] = df["coredata"].apply(utils.abstracts_apply)
        df["references"] = df["item"].apply(utils.reference_apply)
        df["category"] = df["subject-areas"].apply(utils.subject_apply)
        
        # Drop unnecessary columns
        df.drop(columns=["item", "affiliation", "coredata", "idxterms", "language", "authkeywords"], inplace=True)
        
        # Explode subject-areas
        df = df.explode("category", ignore_index=True)
        
        self.data = df

    def null_count(self):
        for c in self.data.columns:
            print(f"Column {c} have {self.data[c].isnull().sum()} null values")

# %%
data = PrepareData()

# %%
data.load_data()
# Out:
# Total data:  20216

# %%
print(f"Before restructure: {data.data.shape}")
# Out:
# Before restructure: (20216, 9)

# %%
data.data
# Out:
#                                                     item  \
# 0      {'ait:process-info': {'ait:status': {'@state':...
# 1      {'ait:process-info': {'ait:status': {'@state':...
# 2      {'ait:process-info': {'ait:status': {'@state':...
# 3      {'ait:process-info': {'ait:status': {'@state':...
# 4      {'ait:process-info': {'ait:status': {'@state':...
# ...                                                  ...
# 20211  {'ait:process-info': {'ait:status': {'@state':...
# 20212  {'ait:process-info': {'ait:status': {'@state':...
# 20213  {'ait:process-info': {'ait:status': {'@state':...
# 20214  {'ait:process-info': {'ait:status': {'@state':...
# 20215  {'ait:process-info': {'ait:status': {'@state':...
#
#                                              affiliation  \
# 0      [{'affiliation-city': 'Stanford', '@id': '6003...
# 1      {'affiliation-city': 'Bangkok', '@id': '600281...
# 2      {'affiliation-city': 'Bangkok', '@id': '600281...
# 3      [{'affiliation-city': 'Hirosaki', '@id': '6003...
# 4      [{'affiliation-city': 'Bangkok', '@id': '60028...
# ...                                                  ...
# 20211  [{'affiliation-city': 'Bangkok', '@id': '60028...
# 20212  {'affiliation-city': 'Bangkok', '@id': '600281...
# 20213  [{'affiliation-city': 'Bangkok', '@id': '60028...
# 20214  [{'affiliation-city': 'Bangkok', '@id': '60028...
# 20215  [{'affiliation-city': 'Bangkok', '@id': '60028...
#
#                                                 coredata  \
# 0      {'srctype': 'b', 'eid': '2-s2.0-85077976956', ...
# 1      {'srctype': 'p', 'eid': '2-s2.0-85060936020', ...
# 2      {'srctype': 'j', 'eid': '2-s2.0-85052201238', ...
# 3      {'srctype': 'j', 'eid': '2-s2.0-85051498032', ...
# 4      {'srctype': 'j', 'eid': '2-s2.0-85050678366', ...
# ...                                                  ...
# 20211  {'srctype': 'j', 'eid': '2-s2.0-85111945558', ...
# 20212  {'srctype': 'j', 'eid': '2-s2.0-85111408415', ...
# 20213  {'srctype': 'j', 'eid': '2-s2.0-85110903700', ...
# 20214  {'srctype': 'j', 'eid': '2-s2.0-85106740832', ...
# 20215  {'srctype': 'j', 'eid': '2-s2.0-85106046890', ...
#
#                                                 idxterms  \
# 0                                                   None
# 1      {'mainterm': [{'$': 'Antenna dimensions', '@we...
# 2      {'mainterm': [{'$': 'Circulating fluidized bed...
# 3      {'mainterm': [{'$': 'Core-shell morphologies',...
# 4      {'mainterm': [{'$': 'acpcPNA', '@weight': 'b',...
# ...                                                  ...
# 20211  {'mainterm': [{'$': 'High selectivity', '@weig...
# 20212  {'mainterm': [{'$': 'Analytical tool', '@weigh...
# 20213                                               None
# 20214                                               None
# 20215                                               None
#
#                    language  \
# 0      {'@xml:lang': 'eng'}
# 1      {'@xml:lang': 'eng'}
# 2      {'@xml:lang': 'eng'}
# 3      {'@xml:lang': 'eng'}
# 4      {'@xml:lang': 'eng'}
# ...                     ...
# 20211  {'@xml:lang': 'eng'}
# 20212  {'@xml:lang': 'eng'}
# 20213  {'@xml:lang': 'eng'}
# 20214  {'@xml:lang': 'eng'}
# 20215  {'@xml:lang': 'eng'}
#
#                                             authkeywords  \
# 0                                                   None
# 1                                                   None
# 2      {'author-keyword': [{'@_fa': 'true', '$': 'Cir...
# 3      {'author-keyword': [{'@_fa': 'true', '$': 'Enc...
# 4      {'author-keyword': [{'@_fa': 'true', '$': 'acp...
# ...                                                  ...
# 20211  {'author-keyword': [{'@_fa': 'true', '$': 'Lon...
# 20212  {'author-keyword': [{'@_fa': 'true', '$': 'Bio...
# 20213  {'author-keyword': [{'@_fa': 'true', '$': 'con...
# 20214  {'author-keyword': [{'@_fa': 'true', '$': 'Ana...
# 20215  {'author-keyword': [{'@_fa': 'true', '$': 'Cam...
#
#                                            subject-areas  \
# 0      {'subject-area': [{'@_fa': 'true', '$': 'Medic...
# 1      {'subject-area': [{'@_fa': 'true', '$': 'Elect...
# 2      {'subject-area': [{'@_fa': 'true', '$': 'Chemi...
# 3      {'subject-area': [{'@_fa': 'true', '$': 'Chemi...
# 4      {'subject-area': [{'@_fa': 'true', '$': 'Analy...
# ...                                                  ...
# 20211  {'subject-area': [{'@_fa': 'true', '$': 'Catal...
# 20212  {'subject-area': [{'@_fa': 'true', '$': 'Analy...
# 20213  {'subject-area': [{'@_fa': 'true', '$': 'Educa...
# 20214  {'subject-area': [{'@_fa': 'true', '$': 'Ecolo...
# 20215  {'subject-area': [{'@_fa': 'true', '$': 'Geogr...
#
#                                                  authors  year
# 0      {'author': [{'ce:given-name': 'Krit', 'preferr...  2018
# 1      {'author': [{'ce:given-name': 'Teerapong', 'pr...  2018
# 2      {'author': [{'ce:given-name': 'Kiattikhoon', '...  2018
# 3      {'author': [{'ce:given-name': 'Jittraporn', 'p...  2018
# 4      {'author': [{'ce:given-name': 'Prinjaporn', 'p...  2018
# ...                                                  ...   ...
# 20211  {'author': [{'ce:given-name': 'Duy', 'preferre...  2023
# 20212  {'author': [{'ce:given-name': 'Waleed', 'prefe...  2023
# 20213  {'author': [{'ce:given-name': 'Tejendra', 'pre...  2023
# 20214  {'author': [{'ce:given-name': 'Ratchaneegorn',...  2023
# 20215  {'author': [{'ce:given-name': 'Vatana', 'prefe...  2023
#
# [20216 rows x 9 columns]

# %%
data.restructure()

# %%
print(f"After restructure: {data.data.shape}")
# Out:
# After restructure: (50064, 8)

# %%
data.data
# Out:
#                                            subject-areas  \
# 0      {'subject-area': [{'@_fa': 'true', '$': 'Medic...
# 1      {'subject-area': [{'@_fa': 'true', '$': 'Elect...
# 2      {'subject-area': [{'@_fa': 'true', '$': 'Elect...
# 3      {'subject-area': [{'@_fa': 'true', '$': 'Chemi...
# 4      {'subject-area': [{'@_fa': 'true', '$': 'Chemi...
# ...                                                  ...
# 50059  {'subject-area': [{'@_fa': 'true', '$': 'Ecolo...
# 50060  {'subject-area': [{'@_fa': 'true', '$': 'Ecolo...
# 50061  {'subject-area': [{'@_fa': 'true', '$': 'Geogr...
# 50062  {'subject-area': [{'@_fa': 'true', '$': 'Geogr...
# 50063  {'subject-area': [{'@_fa': 'true', '$': 'Geogr...
#
#                                                  authors  year           id  \
# 0                   [Krit Pongpirul, Matthew P. Lungren]  2018  85077976956
# 1              [Teerapong Pratumsiri, Panuwat Janpugdee]  2018  85060936020
# 2              [Teerapong Pratumsiri, Panuwat Janpugdee]  2018  85060936020
# 3      [Kiattikhoon Phuakpunk, Benjapon Chalermsinsuw...  2018  85052201238
# 4      [Kiattikhoon Phuakpunk, Benjapon Chalermsinsuw...  2018  85052201238
# ...                                                  ...   ...          ...
# 50059  [Ratchaneegorn Mapanao, Wirat Jiwyam, Nudtha N...  2023  85106740832
# 50060  [Ratchaneegorn Mapanao, Wirat Jiwyam, Nudtha N...  2023  85106740832
# 50061                                      [Vatana Chea]  2023  85106046890
# 50062                                      [Vatana Chea]  2023  85106046890
# 50063                                      [Vatana Chea]  2023  85106046890
#
#                                                    title  \
# 0      Public health and international epidemiology f...
# 1      Flexible Printed Active Antenna for Digital Te...
# 2      Flexible Printed Active Antenna for Digital Te...
# 3      Parametric study of hydrogen production via so...
# 4      Parametric study of hydrogen production via so...
# ...                                                  ...
# 50059  Effects of black soldier fly (Hermetia illucen...
# 50060  Effects of black soldier fly (Hermetia illucen...
# 50061  Effects of remittances on household poverty an...
# 50062  Effects of remittances on household poverty an...
# 50063  Effects of remittances on household poverty an...
#
#                                                abstracts  \
# 0                                                   None
# 1      This paper presents the development of a flexi...
# 2      This paper presents the development of a flexi...
# 3      Computational fluid dynamics was applied for s...
# 4      Computational fluid dynamics was applied for s...
# ...                                                  ...
# 50059  The effects of replacing fish meal protein wit...
# 50060  The effects of replacing fish meal protein wit...
# 50061  The author uses data from the Cambodia Socio-E...
# 50062  The author uses data from the Cambodia Socio-E...
# 50063  The author uses data from the Cambodia Socio-E...
#
#                                               references  \
# 0      [0002667983, 33750367977, 85013970385, 7795302...
# 1      [85006043726, 85046336244, 85060914424, 850463...
# 2      [85006043726, 85046336244, 85060914424, 850463...
# 3      [2942655685, 84908055658, 85052199786, 8485971...
# 4      [2942655685, 84908055658, 85052199786, 8485971...
# ...                                                  ...
# 50059  [84942036010, 0009764501, 84949970831, 8505962...
# 50060  [84942036010, 0009764501, 84949970831, 8505962...
# 50061  [36749086437, 54349107987, 0024885310, 3374585...
# 50062  [36749086437, 54349107987, 0024885310, 3374585...
# 50063  [36749086437, 54349107987, 0024885310, 3374585...
#
#                                                 category
# 0                           (Medicine (all), 2700, MEDI)
# 1      (Electrical and Electronic Engineering, 2208, ...
# 2      (Electronic, Optical and Magnetic Materials, 2...
# 3                          (Chemistry (all), 1600, CHEM)
# 4               (Chemical Engineering (all), 1500, CENG)
# ...                                                  ...
# 50059                              (Ecology, 2303, ENVI)
# 50060                      (Aquatic Science, 1104, AGRI)
# 50061  (Geography, Planning and Development, 3305, SOCI)
# 50062                          (Development, 3303, SOCI)
# 50063  (Political Science and International Relations...
#
# [50064 rows x 8 columns]

# %%
data.data.sample(5)
# Out:
#                                            subject-areas  \
# 3017   {'subject-area': [{'@_fa': 'true', '$': 'Micro...
# 4200   {'subject-area': [{'@_fa': 'true', '$': 'Anato...
# 17142  {'subject-area': [{'@_fa': 'true', '$': 'Ceram...
# 46202  {'subject-area': [{'@_fa': 'true', '$': 'Finan...
# 12333  {'subject-area': [{'@_fa': 'true', '$': 'Mater...
#
#                                                  authors  year           id  \
# 3017   [Nathita Phumthanakorn, Punpichaya Fungwithaya...  2018  85048036785
# 4200        [Eun Jin Woo, Hyunwoo Jung, Tanvaa Tansatit]  2018  85045222768
# 17142  [Tidarut Jirawattanasomkul, Suched Likitlersua...  2020  85082879133
# 46202  [Nopparat Wongsinhirun, Pattanaporn Chatjutham...  2023  85148492722
# 12333  [Thanaporn Wilairat, Nattawut Saechin, Wantane...  2019  85079839423
#
#                                                    title  \
# 3017   Enterotoxin gene profile of methicillin-resist...
# 4200   Cranial index in a modern people of Thai ancestry
# 17142  Structural behaviour of pre-damaged reinforced...
# 46202  Corporate culture and board gender diversity: ...
# 12333  Effects of hot molding parameters on physical ...
#
#                                                abstracts  \
# 3017   Purpose. This study aimed to detect and identi...
# 4200   The present research aims to examine the crani...
# 17142  This paper examines the use of natural jute fa...
# 46202  Exploiting a distinctive measure of corporate ...
# 12333  Hot molding is one of the most important proce...
#
#                                               references  \
# 3017   [84864147868, 79955962281, 84925483592, 338455...
# 4200   [84895168539, 84941189307, 84914151295, 002532...
# 17142  [85046683437, 85050191643, 84974574251, 849035...
# 46202  [85148937971, 70349151758, 84880633653, 848569...
# 12333  [33748773315, 85032568173, 84868330109, 799537...
#
#                                        category
# 3017       (Microbiology (medical), 2726, MEDI)
# 4200                    (Histology, 2722, MEDI)
# 17142     (Ceramics and Composites, 2503, MATE)
# 46202  (Economics and Econometrics, 2002, ECON)
# 12333      (Mechanical Engineering, 2210, ENGI)

# %%
data.null_count()
# Out:
# Column subject-areas have 0 null values
# Column authors have 0 null values
# Column year have 0 null values
# Column id have 0 null values
# Column title have 2 null values
# Column abstracts have 1251 null values
# Column references have 899 null values
# Column category have 0 null values

# %%
data.data.dropna(subset=["abstracts"], inplace=True)
data.data.dropna(subset=["references"], inplace=True)
data.data.dropna(subset=["title"], inplace=True)

data.data.shape
# Out:
# (48227, 8)

# %%
data.data
# Out:
#                                            subject-areas  \
# 1      {'subject-area': [{'@_fa': 'true', '$': 'Elect...
# 2      {'subject-area': [{'@_fa': 'true', '$': 'Elect...
# 3      {'subject-area': [{'@_fa': 'true', '$': 'Chemi...
# 4      {'subject-area': [{'@_fa': 'true', '$': 'Chemi...
# 5      {'subject-area': [{'@_fa': 'true', '$': 'Chemi...
# ...                                                  ...
# 50059  {'subject-area': [{'@_fa': 'true', '$': 'Ecolo...
# 50060  {'subject-area': [{'@_fa': 'true', '$': 'Ecolo...
# 50061  {'subject-area': [{'@_fa': 'true', '$': 'Geogr...
# 50062  {'subject-area': [{'@_fa': 'true', '$': 'Geogr...
# 50063  {'subject-area': [{'@_fa': 'true', '$': 'Geogr...
#
#                                                  authors  year           id  \
# 1              [Teerapong Pratumsiri, Panuwat Janpugdee]  2018  85060936020
# 2              [Teerapong Pratumsiri, Panuwat Janpugdee]  2018  85060936020
# 3      [Kiattikhoon Phuakpunk, Benjapon Chalermsinsuw...  2018  85052201238
# 4      [Kiattikhoon Phuakpunk, Benjapon Chalermsinsuw...  2018  85052201238
# 5      [Kiattikhoon Phuakpunk, Benjapon Chalermsinsuw...  2018  85052201238
# ...                                                  ...   ...          ...
# 50059  [Ratchaneegorn Mapanao, Wirat Jiwyam, Nudtha N...  2023  85106740832
# 50060  [Ratchaneegorn Mapanao, Wirat Jiwyam, Nudtha N...  2023  85106740832
# 50061                                      [Vatana Chea]  2023  85106046890
# 50062                                      [Vatana Chea]  2023  85106046890
# 50063                                      [Vatana Chea]  2023  85106046890
#
#                                                    title  \
# 1      Flexible Printed Active Antenna for Digital Te...
# 2      Flexible Printed Active Antenna for Digital Te...
# 3      Parametric study of hydrogen production via so...
# 4      Parametric study of hydrogen production via so...
# 5      Parametric study of hydrogen production via so...
# ...                                                  ...
# 50059  Effects of black soldier fly (Hermetia illucen...
# 50060  Effects of black soldier fly (Hermetia illucen...
# 50061  Effects of remittances on household poverty an...
# 50062  Effects of remittances on household poverty an...
# 50063  Effects of remittances on household poverty an...
#
#                                                abstracts  \
# 1      This paper presents the development of a flexi...
# 2      This paper presents the development of a flexi...
# 3      Computational fluid dynamics was applied for s...
# 4      Computational fluid dynamics was applied for s...
# 5      Computational fluid dynamics was applied for s...
# ...                                                  ...
# 50059  The effects of replacing fish meal protein wit...
# 50060  The effects of replacing fish meal protein wit...
# 50061  The author uses data from the Cambodia Socio-E...
# 50062  The author uses data from the Cambodia Socio-E...
# 50063  The author uses data from the Cambodia Socio-E...
#
#                                               references  \
# 1      [85006043726, 85046336244, 85060914424, 850463...
# 2      [85006043726, 85046336244, 85060914424, 850463...
# 3      [2942655685, 84908055658, 85052199786, 8485971...
# 4      [2942655685, 84908055658, 85052199786, 8485971...
# 5      [2942655685, 84908055658, 85052199786, 8485971...
# ...                                                  ...
# 50059  [84942036010, 0009764501, 84949970831, 8505962...
# 50060  [84942036010, 0009764501, 84949970831, 8505962...
# 50061  [36749086437, 54349107987, 0024885310, 3374585...
# 50062  [36749086437, 54349107987, 0024885310, 3374585...
# 50063  [36749086437, 54349107987, 0024885310, 3374585...
#
#                                                 category
# 1      (Electrical and Electronic Engineering, 2208, ...
# 2      (Electronic, Optical and Magnetic Materials, 2...
# 3                          (Chemistry (all), 1600, CHEM)
# 4               (Chemical Engineering (all), 1500, CENG)
# 5      (Industrial and Manufacturing Engineering, 220...
# ...                                                  ...
# 50059                              (Ecology, 2303, ENVI)
# 50060                      (Aquatic Science, 1104, AGRI)
# 50061  (Geography, Planning and Development, 3305, SOCI)
# 50062                          (Development, 3303, SOCI)
# 50063  (Political Science and International Relations...
#
# [48227 rows x 8 columns]

# %%
data.save_data()
