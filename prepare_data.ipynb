# %%
import pandas as pd
import json
import os

# %% [markdown]
# # Class for Restructuring

# %% [markdown]
# #### Note for Restructuring
#
# There are 7 columns.
#
# | Column         | Description                         |
# |----------------|-------------------------------------|
# | id             | Unique identifier                   |
# | title          | Title of research                   |
# | category       | tuple (code, subject name, abbrev)  |
# | authors        | List of authors                     |
# | year           | Year of publication                 |
# | abstracts      | Abstract text                       |
# | references     | List of references (id of research) |

# %%
class utils:
    def id_apply(x):
        return x["prism:url"].split("/")[-1]
    
    def title_apply(x):
        if "dc:title" not in x or x["dc:title"] == None:
            return None
        return x["dc:title"]
    
    def author_apply(x):
        # name_list = []
        combine_name = ""
        for author in x["author"]:
            name_to_append = ""
            if "ce:given-name" in author:
                name_to_append = f"{author['ce:given-name']} {author['ce:surname']}"
            else: 
                name_to_append = author["ce:indexed-name"]
            # name_list.append(name_to_append)
            combine_name += name_to_append + ", "
        return combine_name
    
    def abstracts_apply(x):
        if "dc:description" not in x or x["dc:description"] == None:
            return None
        return x["dc:description"]
    
    def reference_apply(x):
        if x["bibrecord"] == None or x["bibrecord"]["tail"] == None or x["bibrecord"]["tail"]["bibliography"] == None or x["bibrecord"]["tail"]["bibliography"]["reference"] == None:
            return None
        reference_list = []
        temp = x["bibrecord"]["tail"]["bibliography"]["reference"]
        if type(temp) != type([]):
            temp = [temp]
        for ref in temp:
            if "ref-info" not in ref or "refd-itemidlist" not in ref["ref-info"]:
                continue
            if type(ref["ref-info"]["refd-itemidlist"]["itemid"]) == type([]):
                for j in ref["ref-info"]["refd-itemidlist"]["itemid"]:
                    if "@idtype" in j and j["@idtype"] == "SGR":
                        reference_list.append(j["$"])
            else:
                if "@idtype" in ref["ref-info"]["refd-itemidlist"]["itemid"] and ref["ref-info"]["refd-itemidlist"]["itemid"]["@idtype"] == "SGR":
                    reference_list.append(ref["ref-info"]["refd-itemidlist"]["itemid"]["$"])
        if len(reference_list) == 0:
            return None
        return reference_list
    
    def subject_apply(x):
        subject_list = []
        for subject in x["subject-area"]:
            name = subject["$"]
            code = subject["@code"]
            abbrev = subject["@abbrev"]
            subject_list.append((name, code, abbrev))
        return subject_list

# %%
class PrepareData:
    def __init__(self) -> None:
        self.data = None
        self.data_dir = "./data"
    
    def load_data(self):
        dfs = []
        dir_list = os.listdir("./data")
        cnt = 0
        for i in dir_list:
            if i == ".DS_Store":
                continue

            # Handle too many data
            # if not (i == "2018" or i == "2019"):
            #     continue
            
            sub_dir = os.path.join("./data", i)
            files = os.listdir(sub_dir)
            for f in files:
                if f == ".DS_Store":
                    continue

                file_path = os.path.join(sub_dir, f)
                with open(file_path, "r") as file:
                    json_data = json.load(file)

                row = {key: value for key, value in json_data["abstracts-retrieval-response"].items()}
                row["year"] = int(i)
                dfs.append(pd.DataFrame([row]))
                cnt += 1

        df = pd.concat(dfs, ignore_index=True)
        print("Total data: ", cnt)
        self.data = df

    def save_data(self, file_name:str):
        if file_name.split(".")[-1] != "csv":
            file_name += ".csv"

        self.data.to_csv(file_name, index=False)

    def restructure(self):
        df = self.data.copy()
        
        df["id"] = df["coredata"].apply(utils.id_apply)
        df["title"] = df["coredata"].apply(utils.title_apply)
        df["authors"] = df["authors"].apply(utils.author_apply)
        df["abstract"] = df["coredata"].apply(utils.abstracts_apply)
        df["references"] = df["item"].apply(utils.reference_apply)
        df["category"] = df["subject-areas"].apply(utils.subject_apply)
        df["source"] = "scopus"
        
        # Drop unnecessary columns
        df.drop(columns=["item", "affiliation", "coredata", "idxterms", "language", "authkeywords", "subject-areas"], inplace=True)
        
        # Explode subject-areas
        # df = df.explode("category", ignore_index=True)
        
        self.data = df

    def null_count(self):
        for c in self.data.columns:
            print(f"Column {c} have {self.data[c].isnull().sum()} null values")

# %%
data = PrepareData()

# %%
data.load_data()
# Out:
# Total data:  20216

# %%
print(f"Before restructure: {data.data.shape}")
# Out:
# Before restructure: (20216, 9)

# %%
data.data
# Out:
#                                                     item  \
# 0      {'ait:process-info': {'ait:status': {'@state':...
# 1      {'ait:process-info': {'ait:status': {'@state':...
# 2      {'ait:process-info': {'ait:status': {'@state':...
# 3      {'ait:process-info': {'ait:status': {'@state':...
# 4      {'ait:process-info': {'ait:status': {'@state':...
# ...                                                  ...
# 20211  {'ait:process-info': {'ait:status': {'@state':...
# 20212  {'ait:process-info': {'ait:status': {'@state':...
# 20213  {'ait:process-info': {'ait:status': {'@state':...
# 20214  {'ait:process-info': {'ait:status': {'@state':...
# 20215  {'ait:process-info': {'ait:status': {'@state':...
#
#                                              affiliation  \
# 0      [{'affiliation-city': 'Bangkok', '@id': '60199...
# 1      {'affiliation-city': 'Bangkok', '@id': '600281...
# 2      [{'affiliation-city': 'Bangkok', '@id': '60091...
# 3      [{'affiliation-city': 'Riverside', '@id': '600...
# 4      {'affiliation-city': 'Bangkok', '@id': '600221...
# ...                                                  ...
# 20211  [{'affiliation-city': 'Bangkok', '@id': '60022...
# 20212  {'affiliation-city': 'Bangkok', '@id': '600281...
# 20213  {'affiliation-city': 'Bangkok', '@id': '600281...
# 20214  [{'affiliation-city': 'Bangkok', '@id': '60028...
# 20215  [{'affiliation-city': 'Tai'an', '@id': '601614...
#
#                                                 coredata  \
# 0      {'srctype': 'j', 'eid': '2-s2.0-85114881247', ...
# 1      {'srctype': 'j', 'eid': '2-s2.0-85130612598', ...
# 2      {'srctype': 'j', 'prism:issueIdentifier': '3',...
# 3      {'srctype': 'j', 'eid': '2-s2.0-85138732480', ...
# 4      {'srctype': 'j', 'eid': '2-s2.0-85123852067', ...
# ...                                                  ...
# 20211  {'srctype': 'j', 'eid': '2-s2.0-85049127661', ...
# 20212  {'srctype': 'k', 'eid': '2-s2.0-85026629813', ...
# 20213  {'srctype': 'j', 'eid': '2-s2.0-85051822557', ...
# 20214  {'srctype': 'j', 'prism:issueIdentifier': '2',...
# 20215  {'srctype': 'j', 'eid': '2-s2.0-85045448329', ...
#
#                                                 idxterms  \
# 0      {'mainterm': [{'$': 'Adult', '@weight': 'b', '...
# 1                                                   None
# 2      {'mainterm': [{'$': 'Animals', '@weight': 'b',...
# 3      {'mainterm': [{'$': 'Atrial Fibrillation', '@w...
# 4                                                   None
# ...                                                  ...
# 20211                                               None
# 20212                                               None
# 20213  {'mainterm': [{'$': 'Antifungal Agents', '@wei...
# 20214                                               None
# 20215  {'mainterm': [{'$': 'Brain Neoplasms', '@weigh...
#
#                    language  \
# 0      {'@xml:lang': 'eng'}
# 1      {'@xml:lang': 'eng'}
# 2      {'@xml:lang': 'eng'}
# 3      {'@xml:lang': 'eng'}
# 4      {'@xml:lang': 'eng'}
# ...                     ...
# 20211  {'@xml:lang': 'eng'}
# 20212  {'@xml:lang': 'eng'}
# 20213  {'@xml:lang': 'eng'}
# 20214  {'@xml:lang': 'eng'}
# 20215  {'@xml:lang': 'eng'}
#
#                                             authkeywords  \
# 0                                                   None
# 1      {'author-keyword': [{'@_fa': 'true', '$': 'Bus...
# 2      {'author-keyword': [{'@_fa': 'true', '$': 'aqu...
# 3                                                   None
# 4      {'author-keyword': [{'@_fa': 'true', '$': 'Cad...
# ...                                                  ...
# 20211  {'author-keyword': [{'@_fa': 'true', '$': 'End...
# 20212  {'author-keyword': [{'@_fa': 'true', '$': 'And...
# 20213  {'author-keyword': [{'@_fa': 'true', '$': 'Cor...
# 20214  {'author-keyword': [{'@_fa': 'true', '$': 'Bio...
# 20215  {'author-keyword': [{'@_fa': 'true', '$': 'Ext...
#
#                                            subject-areas  \
# 0      {'subject-area': [{'@_fa': 'true', '$': 'Derma...
# 1      {'subject-area': [{'@_fa': 'true', '$': 'Compu...
# 2      {'subject-area': [{'@_fa': 'true', '$': 'Physi...
# 3      {'subject-area': [{'@_fa': 'true', '$': 'Advan...
# 4      {'subject-area': [{'@_fa': 'true', '$': 'Anato...
# ...                                                  ...
# 20211  {'subject-area': [{'@_fa': 'true', '$': 'Medic...
# 20212  {'subject-area': [{'@_fa': 'true', '$': 'Artif...
# 20213  {'subject-area': [{'@_fa': 'true', '$': 'Medic...
# 20214  {'subject-area': [{'@_fa': 'true', '$': 'Chemi...
# 20215  {'subject-area': [{'@_fa': 'true', '$': 'Oncol...
#
#                                                  authors  year
# 0      {'author': [{'preferred-name': {'ce:given-name...  2022
# 1      {'author': [{'ce:given-name': 'Pakkaporn', 'pr...  2022
# 2      {'author': [{'ce:given-name': 'Chonchanok', 'p...  2022
# 3      {'author': [{'ce:given-name': 'Narut', 'prefer...  2022
# 4      {'author': [{'ce:given-name': 'Danaithep', 'pr...  2022
# ...                                                  ...   ...
# 20211  {'author': [{'ce:given-name': 'Pradermchai', '...  2018
# 20212  {'author': [{'ce:given-name': 'Kwandee', 'pref...  2018
# 20213  {'author': [{'ce:given-name': 'Marisa', 'prefe...  2018
# 20214  {'author': [{'ce:given-name': 'Pimsuda', 'pref...  2018
# 20215  {'author': [{'ce:given-name': 'Terence T.', 'p...  2018
#
# [20216 rows x 9 columns]

# %%
data.restructure()

# %%
print(f"After restructure: {data.data.shape}")
# Out:
# After restructure: (20216, 8)

# %%
data.data
# Out:
#                                                  authors  year           id  \
# 0      Rujitharanawong C., Tuchinda P., Chularojanamo...  2022  85114881247
# 1          Pakkaporn Rungruengkultorn, Somjai Boonsiri,   2022  85130612598
# 2      Chonchanok Muangnapoh, Eakapong Tamboon, Neung...  2022  85133214239
# 3      Narut Prasitlumkum, Ronpichai Chokesuwattanask...  2022  85138732480
# 4      Danaithep Limskul, Jirun Apinun, Thanasil Huan...  2022  85123852067
# ...                                                  ...   ...          ...
# 20211  Pradermchai Kongkam, Veeravich Jaruvongvanich,...  2018  85049127661
# 20212        Kwandee Phetcharakarn, Twittie Senivongse,   2018  85026629813
# 20213  Marisa Taechajongjintana, Ngamjit Kasetsuwan, ...  2018  85051822557
# 20214  Pimsuda Pansa-Ngat, Trin Jedsukontorn, Mali Hu...  2018  85041960467
# 20215  Terence T. Sio, Anussara Prayongrat, Yun Zhang...  2018  85045448329
#
#                                                    title  \
# 0      Direct immunofluorescence staining patterns co...
# 1      Warehouse Processes Improvement Using Lean Six...
# 2      Multilocus Sequence Typing and Virulence Poten...
# 3      Atrial fibrillation ablation in hemodialysis p...
# 4      Anatomy of the coracoid process in Thais: Cada...
# ...                                                  ...
# 20211  Multi-detector computed tomography versus endo...
# 20212  Heuristic-based usability evaluation tool for ...
# 20213  Effectiveness of voriconazole and corneal cros...
# 20214  Optimal hydrogen production coupled with pollu...
# 20215  The Road Less Traveled: Should We Omit Prophyl...
#
#                                                 abstract  \
# 0      This retrospective study performed to investig...
# 1      Warehouse processes are the primary activities...
# 2      Vibrio parahaemolyticus is a Gram-negative, fo...
# 3                                                   None
# 4      Introduction: The aim of this study was to inv...
# ...                                                  ...
# 20211  Objective: Endoscopic ultrasonography [EUS] ha...
# 20212  Heuristic evaluation is a popular method for e...
# 20213  Background: We report a rare case of Phialopho...
# 20214  This work aimed to produce hydrogen (H2) simul...
# 20215  New randomized data from Japan have raised que...
#
#                                               references  \
# 0      [37549006776, 85063567734, 84899635287, 850251...
# 1      [3843106887, 35948936348, 0003858901, 84923090...
# 2      [85074709058, 0024526678, 85042353919, 8490683...
# 3      [84899623290, 76749163232, 85041417343, 850630...
# 4      [0023103425, 0000627515, 0346996881, 848635193...
# ...                                                  ...
# 20211  [78649352788, 77954344963, 78349285165, 849587...
# 20212  [0004257599, 85022187784, 33744832544, 8502666...
# 20213  [84908551974, 0014002794, 0017140495, 58149174...
# 20214  [0022873628, 84940061463, 29144508454, 8497090...
# 20215  [85037152235, 34250351907, 0345062339, 3042759...
#
#                                                 category  source
# 0                            [(Dermatology, 2708, MEDI)]  scopus
# 1      [(Computer Science (miscellaneous), 1701, COMP...  scopus
# 2      [(Physiology, 1314, BIOC), (Ecology, 2303, ENV...  scopus
# 3      [(Advanced and Specialized Nursing, 2902, NURS...  scopus
# 4                                [(Anatomy, 2702, MEDI)]  scopus
# ...                                                  ...     ...
# 20211                     [(Medicine (all), 2700, MEDI)]  scopus
# 20212            [(Artificial Intelligence, 1702, COMP)]  scopus
# 20213                     [(Medicine (all), 2700, MEDI)]  scopus
# 20214  [(Chemical Engineering (all), 1500, CENG), (Ma...  scopus
# 20215  [(Oncology, 2730, MEDI), (Pulmonary and Respir...  scopus
#
# [20216 rows x 8 columns]

# %%
data.data.sample(5)
# Out:
#                                                  authors  year           id  \
# 1775   Claire M. Lawley, Matthew Tester, Shubhayan Sa...  2022  85140055861
# 6727   Chetan Chauhan, Rajesh Kumar, Anju Saini, Raj ...  2023  85169978316
# 17908                     Rodtassana C., Tanner E.V.J.,   2018  85042637153
# 5622   Asanee Somdee, Surangkana Wannapop, Nuchanapor...  2023  85143724257
# 16220  Anca Chelariu-Raicu, Charles F. Levenback, Bri...  2020  85095457074
#
#                                                    title  \
# 1775   Life-threatening cardiac arrhythmia and sudden...
# 6727   Rare coordination behavior of triethanolamine ...
# 17908  Litter removal in a tropical rain forest reduc...
# 5622   Enhanced charge carrier density of a p-n BiOCl...
# 16220  Phase Ib/II study of weekly topotecan and dail...
#
#                                                 abstract  \
# 1775   Background: Electronic gaming has recently bee...
# 6727   Herein, unusual and rare coordination behavior...
# 17908  Many old-growth lowland tropical rain forests ...
# 5622   Pure and doped p-n BiOCl/BiVO4 heterostructure...
# 16220  Introduction 50-70% of epithelial ovarian canc...
#
#                                               references  \
# 1775   [85072387788, 85084791889, 84889856570, 850633...
# 6727   [85040186048, 84855577188, 85092175918, 337481...
# 17908  [72449172894, 77958608000, 0003461899, 0022889...
# 5622   [0035891138, 85064490044, 85120574487, 8507388...
# 16220  [85034257569, 4143087249, 0036499282, 79961139...
#
#                                                 category  source
# 1775   [(Cardiology and Cardiovascular Medicine, 2705...  scopus
# 6727   [(Analytical Chemistry, 1602, CHEM), (Spectros...  scopus
# 17908  [(Ecology, Evolution, Behavior and Systematics...  scopus
# 5622   [(Mechanics of Materials, 2211, ENGI), (Mechan...  scopus
# 16220  [(Oncology, 2730, MEDI), (Obstetrics and Gynec...  scopus

# %%
data.null_count()
# Out:
# Column authors have 0 null values
# Column year have 0 null values
# Column id have 0 null values
# Column title have 1 null values
# Column abstract have 665 null values
# Column references have 411 null values
# Column category have 0 null values
# Column source have 0 null values

# %%
data.data.dropna(subset=["abstract"], inplace=True)
data.data.dropna(subset=["references"], inplace=True)
data.data.dropna(subset=["title"], inplace=True)

data.data.shape
# Out:
# (19275, 8)

# %%
data.data
# Out:
#                                                  authors  year           id  \
# 0      Rujitharanawong C., Tuchinda P., Chularojanamo...  2022  85114881247
# 1          Pakkaporn Rungruengkultorn, Somjai Boonsiri,   2022  85130612598
# 2      Chonchanok Muangnapoh, Eakapong Tamboon, Neung...  2022  85133214239
# 4      Danaithep Limskul, Jirun Apinun, Thanasil Huan...  2022  85123852067
# 5      Wichanan Wannasrichan, Htut Htut Htoo, Rubsade...  2022  85140221720
# ...                                                  ...   ...          ...
# 20211  Pradermchai Kongkam, Veeravich Jaruvongvanich,...  2018  85049127661
# 20212        Kwandee Phetcharakarn, Twittie Senivongse,   2018  85026629813
# 20213  Marisa Taechajongjintana, Ngamjit Kasetsuwan, ...  2018  85051822557
# 20214  Pimsuda Pansa-Ngat, Trin Jedsukontorn, Mali Hu...  2018  85041960467
# 20215  Terence T. Sio, Anussara Prayongrat, Yun Zhang...  2018  85045448329
#
#                                                    title  \
# 0      Direct immunofluorescence staining patterns co...
# 1      Warehouse Processes Improvement Using Lean Six...
# 2      Multilocus Sequence Typing and Virulence Poten...
# 4      Anatomy of the coracoid process in Thais: Cada...
# 5      Phage-resistant Pseudomonas aeruginosa against...
# ...                                                  ...
# 20211  Multi-detector computed tomography versus endo...
# 20212  Heuristic-based usability evaluation tool for ...
# 20213  Effectiveness of voriconazole and corneal cros...
# 20214  Optimal hydrogen production coupled with pollu...
# 20215  The Road Less Traveled: Should We Omit Prophyl...
#
#                                                 abstract  \
# 0      This retrospective study performed to investig...
# 1      Warehouse processes are the primary activities...
# 2      Vibrio parahaemolyticus is a Gram-negative, fo...
# 4      Introduction: The aim of this study was to inv...
# 5      Pseudomonas aeruginosa, a major cause of nosoc...
# ...                                                  ...
# 20211  Objective: Endoscopic ultrasonography [EUS] ha...
# 20212  Heuristic evaluation is a popular method for e...
# 20213  Background: We report a rare case of Phialopho...
# 20214  This work aimed to produce hydrogen (H2) simul...
# 20215  New randomized data from Japan have raised que...
#
#                                               references  \
# 0      [37549006776, 85063567734, 84899635287, 850251...
# 1      [3843106887, 35948936348, 0003858901, 84923090...
# 2      [85074709058, 0024526678, 85042353919, 8490683...
# 4      [0023103425, 0000627515, 0346996881, 848635193...
# 5      [0038392706, 85017428187, 84860243334, 8510269...
# ...                                                  ...
# 20211  [78649352788, 77954344963, 78349285165, 849587...
# 20212  [0004257599, 85022187784, 33744832544, 8502666...
# 20213  [84908551974, 0014002794, 0017140495, 58149174...
# 20214  [0022873628, 84940061463, 29144508454, 8497090...
# 20215  [85037152235, 34250351907, 0345062339, 3042759...
#
#                                                 category  source
# 0                            [(Dermatology, 2708, MEDI)]  scopus
# 1      [(Computer Science (miscellaneous), 1701, COMP...  scopus
# 2      [(Physiology, 1314, BIOC), (Ecology, 2303, ENV...  scopus
# 4                                [(Anatomy, 2702, MEDI)]  scopus
# 5      [(Microbiology, 2404, IMMU), (Microbiology (me...  scopus
# ...                                                  ...     ...
# 20211                     [(Medicine (all), 2700, MEDI)]  scopus
# 20212            [(Artificial Intelligence, 1702, COMP)]  scopus
# 20213                     [(Medicine (all), 2700, MEDI)]  scopus
# 20214  [(Chemical Engineering (all), 1500, CENG), (Ma...  scopus
# 20215  [(Oncology, 2730, MEDI), (Pulmonary and Respir...  scopus
#
# [19275 rows x 8 columns]

# %%
data.save_data(file_name="scopus_unexplode_data.csv")
