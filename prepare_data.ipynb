# %%
import pandas as pd
import json
import os

# %% [markdown]
# # Class for Restructuring

# %% [markdown]
# #### Note for Destructuring
#
# - dc:description can be unexist
# - abstract can be null
# - authkeywords can be null
# - reference can be null (tail can be null)

# %%
class utils:
    def author_apply(x):
        name_list = []
        for author in x["author"]:
            name_to_append = ""
            if "ce:given-name" in author:
                name_to_append = f"{author['ce:given-name']} {author['ce:surname']}"
            else: 
                name_to_append = author["ce:indexed-name"]
            name_list.append(name_to_append)
        return name_list
    
    def citation_apply(x):
        citation_list = []
        if x == None:
            return [None]
        if type(x["author-keyword"]) == type(dict()):
            return [x["author-keyword"]["$"]]
        for citation in x["author-keyword"]:
            citation_list.append(citation["$"])
        return citation_list
    
    def reference_apply(x):
        reference_list = []
        if x["bibrecord"]["tail"] == None:
            return []
        if x["bibrecord"]["tail"]["bibliography"] == None:
            print("a")
            return []
        if x["bibrecord"]["tail"]["bibliography"]["reference"] == None:
            print("b")
            return []
        if type(x["bibrecord"]["tail"]["bibliography"]["reference"]) == type(dict()):
            reference_list.append(x["bibrecord"]["tail"]["bibliography"]["reference"]["ref-fulltext"] if "ref-fulltext" in x["bibrecord"]["tail"]["bibliography"]["reference"] else "")
            return reference_list
        for ref in x["bibrecord"]["tail"]["bibliography"]["reference"]:
            reference_list.append(ref["ref-fulltext"] if "ref-fulltext" in ref else "")
        return reference_list
    
    def subject_apply(x):
        subject_list = []
        for subject in x["subject-area"]:
            subject_list.append(subject["$"])
        return subject_list

# %%
class PrepareData:
    def __init__(self) -> None:
        self.data = None
        self.data_dir = "./data"
    
    def load_data(self):
        dfs = []
        dir_list = os.listdir("./data")
        cnt = 0
        for i in dir_list:
            if i == ".DS_Store":
                continue

            # Handle too many data
            # if not (i == "2018" or i == "2019"):
            #     continue
            
            sub_dir = os.path.join("./data", i)
            files = os.listdir(sub_dir)
            for f in files:
                if f == ".DS_Store":
                    continue

                file_path = os.path.join(sub_dir, f)
                with open(file_path, "r") as file:
                    json_data = json.load(file)

                row = {key: value for key, value in json_data["abstracts-retrieval-response"].items()}
                row["year"] = int(i)
                dfs.append(pd.DataFrame([row]))
                cnt += 1

        df = pd.concat(dfs, ignore_index=True)
        print("Total data: ", cnt)
        self.data = df

    def save_data(self):
        self.data.to_csv("data.csv", index=False)

    def restructure(self):
        df = self.data.copy()
        
        df["id"] = df["coredata"].apply(lambda x: x["prism:url"].split("/")[-1])
        df["authors"] = df["authors"].apply(utils.author_apply)
        df["description"] = df["coredata"].apply(lambda x: x["dc:description"] if "dc:description" in x else "")
        df["abstracts"] = df["item"].apply(lambda x: x["bibrecord"]["head"]["abstracts"])
        df["citation"] = df["authkeywords"].apply(utils.citation_apply)
        df["references"] = df["item"].apply(utils.reference_apply)
        df["subject-areas"] = df["subject-areas"].apply(utils.subject_apply)
        df = df.explode("citation", ignore_index=True)
        
        df.drop(columns=["item", "affiliation", "coredata", "idxterms", "language", "authkeywords"], inplace=True)
        self.data = df

# %%
data = PrepareData()

# %%
data.load_data()
# Out:
# Total data:  20216

# %%
print(f"Before restructure: {data.data.shape}")
# Out:
# Before restructure: (20216, 9)

# %%
data.data
# Out:
#                                                     item  \
# 0      {'ait:process-info': {'ait:status': {'@state':...
# 1      {'ait:process-info': {'ait:status': {'@state':...
# 2      {'ait:process-info': {'ait:status': {'@state':...
# 3      {'ait:process-info': {'ait:status': {'@state':...
# 4      {'ait:process-info': {'ait:status': {'@state':...
# ...                                                  ...
# 20211  {'ait:process-info': {'ait:status': {'@state':...
# 20212  {'ait:process-info': {'ait:status': {'@state':...
# 20213  {'ait:process-info': {'ait:status': {'@state':...
# 20214  {'ait:process-info': {'ait:status': {'@state':...
# 20215  {'ait:process-info': {'ait:status': {'@state':...
#
#                                              affiliation  \
# 0      {'affiliation-city': 'Bangkok', '@id': '600281...
# 1      [{'affiliation-city': 'Abu Dhabi', '@id': '601...
# 2      [{'affiliation-city': 'Bangkok', '@id': '60002...
# 3      [{'affiliation-city': 'Linkoping', '@id': '600...
# 4      [{'affiliation-city': 'Bangkok', '@id': '60028...
# ...                                                  ...
# 20211  [{'affiliation-city': 'Khon Kaen', '@id': '600...
# 20212  [{'affiliation-city': 'Tokyo', '@id': '6017860...
# 20213  [{'affiliation-city': 'Bangkok', '@id': '60028...
# 20214  {'affiliation-city': 'Bangkok', '@id': '600281...
# 20215  [{'affiliation-city': 'Coventry', '@id': '6011...
#
#                                                 coredata  \
# 0      {'srctype': 'j', 'eid': '2-s2.0-85131139456', ...
# 1      {'srctype': 'j', 'eid': '2-s2.0-85121351780', ...
# 2      {'srctype': 'j', 'eid': '2-s2.0-85131660961', ...
# 3      {'srctype': 'j', 'prism:issueIdentifier': '6',...
# 4      {'srctype': 'j', 'eid': '2-s2.0-85143878806', ...
# ...                                                  ...
# 20211  {'srctype': 'k', 'eid': '2-s2.0-85063382127', ...
# 20212  {'srctype': 'j', 'eid': '2-s2.0-85047370082', ...
# 20213  {'srctype': 'j', 'eid': '2-s2.0-85042389729', ...
# 20214  {'srctype': 'j', 'eid': '2-s2.0-85055194236', ...
# 20215  {'srctype': 'j', 'eid': '2-s2.0-85041549068', ...
#
#                                                 idxterms  \
# 0                                                   None
# 1      {'mainterm': [{'$': 'COVID-19', '@weight': 'a'...
# 2                                                   None
# 3      {'mainterm': [{'$': 'Anisotropic strain', '@we...
# 4                                                   None
# ...                                                  ...
# 20211  {'mainterm': [{'$': 'Actual evapotranspiration...
# 20212  {'mainterm': [{'$': 'Carcinoma, Hepatocellular...
# 20213                                               None
# 20214                                               None
# 20215                                               None
#
#                    language  \
# 0      {'@xml:lang': 'eng'}
# 1      {'@xml:lang': 'eng'}
# 2      {'@xml:lang': 'eng'}
# 3      {'@xml:lang': 'eng'}
# 4      {'@xml:lang': 'eng'}
# ...                     ...
# 20211  {'@xml:lang': 'eng'}
# 20212  {'@xml:lang': 'eng'}
# 20213  {'@xml:lang': 'eng'}
# 20214  {'@xml:lang': 'eng'}
# 20215  {'@xml:lang': 'eng'}
#
#                                             authkeywords  \
# 0      {'author-keyword': [{'@_fa': 'true', '$': 'Ant...
# 1      {'author-keyword': [{'@_fa': 'true', '$': 'car...
# 2      {'author-keyword': [{'@_fa': 'true', '$': 'Alz...
# 3                                                   None
# 4      {'author-keyword': [{'@_fa': 'true', '$': 'Bra...
# ...                                                  ...
# 20211  {'author-keyword': [{'@_fa': 'true', '$': 'Act...
# 20212                                               None
# 20213  {'author-keyword': [{'@_fa': 'true', '$': 'Mot...
# 20214  {'author-keyword': [{'@_fa': 'true', '$': 'Can...
# 20215                                               None
#
#                                            subject-areas  \
# 0      {'subject-area': [{'@_fa': 'true', '$': 'Food ...
# 1      {'subject-area': [{'@_fa': 'true', '$': 'Surge...
# 2      {'subject-area': [{'@_fa': 'true', '$': 'Neuro...
# 3      {'subject-area': [{'@_fa': 'true', '$': 'Physi...
# 4      {'subject-area': [{'@_fa': 'true', '$': 'Physi...
# ...                                                  ...
# 20211  {'subject-area': [{'@_fa': 'true', '$': 'Artif...
# 20212  {'subject-area': [{'@_fa': 'true', '$': 'Multi...
# 20213  {'subject-area': [{'@_fa': 'true', '$': 'Medic...
# 20214  {'subject-area': [{'@_fa': 'true', '$': 'Veter...
# 20215  {'subject-area': [{'@_fa': 'true', '$': 'Econo...
#
#                                                  authors  year
# 0      {'author': [{'ce:given-name': 'Sureerat', 'pre...  2022
# 1      {'author': [{'ce:given-name': 'Abhijit V.', 'p...  2022
# 2      {'author': [{'ce:given-name': 'Solaphat', 'pre...  2022
# 3      {'author': [{'ce:given-name': 'Erik', 'preferr...  2022
# 4      {'author': [{'ce:given-name': 'Kunanya', 'pref...  2022
# ...                                                  ...   ...
# 20211  {'author': [{'ce:given-name': 'Panath', 'prefe...  2018
# 20212  {'author': [{'ce:given-name': 'Hiromi', 'prefe...  2018
# 20213  {'author': [{'ce:given-name': 'Sirinuch', 'pre...  2018
# 20214  {'author': [{'ce:given-name': 'Chutamas', 'pre...  2018
# 20215  {'author': [{'ce:given-name': 'Warn N.', 'pref...  2018
#
# [20216 rows x 9 columns]

# %%
data.restructure()

# %%
print(f"After restructure: {data.data.shape}")
# Out:
# After restructure: (86836, 8)

# %%
data.data
# Out:
#                                            subject-areas  \
# 0      [Food Science, Physiology, Animal Science and ...
# 1      [Food Science, Physiology, Animal Science and ...
# 2      [Food Science, Physiology, Animal Science and ...
# 3      [Food Science, Physiology, Animal Science and ...
# 4      [Food Science, Physiology, Animal Science and ...
# ...                                                  ...
# 86831                                 [Veterinary (all)]
# 86832                                 [Veterinary (all)]
# 86833                                 [Veterinary (all)]
# 86834                                 [Veterinary (all)]
# 86835                       [Economics and Econometrics]
#
#                                                  authors  year           id  \
# 0      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 1      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 2      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 3      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 4      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# ...                                                  ...   ...          ...
# 86831  [Chutamas Benjanirut, Chanakarn Wongsangchan, ...  2018  85055194236
# 86832  [Chutamas Benjanirut, Chanakarn Wongsangchan, ...  2018  85055194236
# 86833  [Chutamas Benjanirut, Chanakarn Wongsangchan, ...  2018  85055194236
# 86834  [Chutamas Benjanirut, Chanakarn Wongsangchan, ...  2018  85055194236
# 86835  [Warn N. Lekfuangfu, Nattavudh Powdthavee, Nel...  2018  85041549068
#
#                                              description  \
# 0      Objective: Microencapsulation is a technique t...
# 1      Objective: Microencapsulation is a technique t...
# 2      Objective: Microencapsulation is a technique t...
# 3      Objective: Microencapsulation is a technique t...
# 4      Objective: Microencapsulation is a technique t...
# ...                                                  ...
# 86831  Canine cognitive dysfunction syndrome (CDS) is...
# 86832  Canine cognitive dysfunction syndrome (CDS) is...
# 86833  Canine cognitive dysfunction syndrome (CDS) is...
# 86834  Canine cognitive dysfunction syndrome (CDS) is...
# 86835  This article builds upon Cunha's (2015) subjec...
#
#                                                abstracts  \
# 0      Copyright © 2022 by Animal BioscienceObjective...
# 1      Copyright © 2022 by Animal BioscienceObjective...
# 2      Copyright © 2022 by Animal BioscienceObjective...
# 3      Copyright © 2022 by Animal BioscienceObjective...
# 4      Copyright © 2022 by Animal BioscienceObjective...
# ...                                                  ...
# 86831  © 2018 Chulalongkorn University Printing House...
# 86832  © 2018 Chulalongkorn University Printing House...
# 86833  © 2018 Chulalongkorn University Printing House...
# 86834  © 2018 Chulalongkorn University Printing House...
# 86835  © 2016 Royal Economic SocietyThis article buil...
#
#                                     citation  \
# 0                       Antioxidant Capacity
# 1                                  Basil Oil
# 2                            Broiler Chicken
# 3                             Gut Morphology
# 4                         Microencapsulation
# ...                                      ...
# 86831  Canine cognitive dysfunction syndrome
# 86832                             Prevalence
# 86833                           Risk factors
# 86834                               Thailand
# 86835                                   None
#
#                                               references
# 0      [Attia YA, Al-Harthi MA, Sh. Elnaggar A. Produ...
# 1      [Attia YA, Al-Harthi MA, Sh. Elnaggar A. Produ...
# 2      [Attia YA, Al-Harthi MA, Sh. Elnaggar A. Produ...
# 3      [Attia YA, Al-Harthi MA, Sh. Elnaggar A. Produ...
# 4      [Attia YA, Al-Harthi MA, Sh. Elnaggar A. Produ...
# ...                                                  ...
# 86831  [Azkona G, Garciá-Belenguer S, Chacón G, Rosad...
# 86832  [Azkona G, Garciá-Belenguer S, Chacón G, Rosad...
# 86833  [Azkona G, Garciá-Belenguer S, Chacón G, Rosad...
# 86834  [Azkona G, Garciá-Belenguer S, Chacón G, Rosad...
# 86835  [Anger, S. (2012). ‘Intergenerational transmis...
#
# [86836 rows x 8 columns]

# %%
data.data
# Out:
#                                            subject-areas  \
# 0      [Food Science, Physiology, Animal Science and ...
# 1      [Food Science, Physiology, Animal Science and ...
# 2      [Food Science, Physiology, Animal Science and ...
# 3      [Food Science, Physiology, Animal Science and ...
# 4      [Food Science, Physiology, Animal Science and ...
# ...                                                  ...
# 86831                                 [Veterinary (all)]
# 86832                                 [Veterinary (all)]
# 86833                                 [Veterinary (all)]
# 86834                                 [Veterinary (all)]
# 86835                       [Economics and Econometrics]
#
#                                                  authors  year           id  \
# 0      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 1      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 2      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 3      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 4      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# ...                                                  ...   ...          ...
# 86831  [Chutamas Benjanirut, Chanakarn Wongsangchan, ...  2018  85055194236
# 86832  [Chutamas Benjanirut, Chanakarn Wongsangchan, ...  2018  85055194236
# 86833  [Chutamas Benjanirut, Chanakarn Wongsangchan, ...  2018  85055194236
# 86834  [Chutamas Benjanirut, Chanakarn Wongsangchan, ...  2018  85055194236
# 86835  [Warn N. Lekfuangfu, Nattavudh Powdthavee, Nel...  2018  85041549068
#
#                                              description  \
# 0      Objective: Microencapsulation is a technique t...
# 1      Objective: Microencapsulation is a technique t...
# 2      Objective: Microencapsulation is a technique t...
# 3      Objective: Microencapsulation is a technique t...
# 4      Objective: Microencapsulation is a technique t...
# ...                                                  ...
# 86831  Canine cognitive dysfunction syndrome (CDS) is...
# 86832  Canine cognitive dysfunction syndrome (CDS) is...
# 86833  Canine cognitive dysfunction syndrome (CDS) is...
# 86834  Canine cognitive dysfunction syndrome (CDS) is...
# 86835  This article builds upon Cunha's (2015) subjec...
#
#                                                abstracts  \
# 0      Copyright © 2022 by Animal BioscienceObjective...
# 1      Copyright © 2022 by Animal BioscienceObjective...
# 2      Copyright © 2022 by Animal BioscienceObjective...
# 3      Copyright © 2022 by Animal BioscienceObjective...
# 4      Copyright © 2022 by Animal BioscienceObjective...
# ...                                                  ...
# 86831  © 2018 Chulalongkorn University Printing House...
# 86832  © 2018 Chulalongkorn University Printing House...
# 86833  © 2018 Chulalongkorn University Printing House...
# 86834  © 2018 Chulalongkorn University Printing House...
# 86835  © 2016 Royal Economic SocietyThis article buil...
#
#                                     citation  \
# 0                       Antioxidant Capacity
# 1                                  Basil Oil
# 2                            Broiler Chicken
# 3                             Gut Morphology
# 4                         Microencapsulation
# ...                                      ...
# 86831  Canine cognitive dysfunction syndrome
# 86832                             Prevalence
# 86833                           Risk factors
# 86834                               Thailand
# 86835                                   None
#
#                                               references
# 0      [Attia YA, Al-Harthi MA, Sh. Elnaggar A. Produ...
# 1      [Attia YA, Al-Harthi MA, Sh. Elnaggar A. Produ...
# 2      [Attia YA, Al-Harthi MA, Sh. Elnaggar A. Produ...
# 3      [Attia YA, Al-Harthi MA, Sh. Elnaggar A. Produ...
# 4      [Attia YA, Al-Harthi MA, Sh. Elnaggar A. Produ...
# ...                                                  ...
# 86831  [Azkona G, Garciá-Belenguer S, Chacón G, Rosad...
# 86832  [Azkona G, Garciá-Belenguer S, Chacón G, Rosad...
# 86833  [Azkona G, Garciá-Belenguer S, Chacón G, Rosad...
# 86834  [Azkona G, Garciá-Belenguer S, Chacón G, Rosad...
# 86835  [Anger, S. (2012). ‘Intergenerational transmis...
#
# [86836 rows x 8 columns]

# %%
data.save_data()
