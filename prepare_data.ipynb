# %%
import pandas as pd
import json
import os

# %% [markdown]
# # Class for Restructuring

# %% [markdown]
# #### Note for Restructuring
#
# There are 7 columns.
#
# | Column         | Description                         |
# |----------------|-------------------------------------|
# | id             | Unique identifier                   |
# | title          | Title of research                   |
# | subject-areas  | tuple (code, subject name, abbrev)  |
# | authors        | List of authors                     |
# | year           | Year of publication                 |
# | abstracts      | Abstract text                       |
# | references     | List of references (id of research) |

# %%
class utils:
    def id_apply(x):
        return x["prism:url"].split("/")[-1]
    
    def title_apply(x):
        if "dc:title" not in x or x["dc:title"] == None:
            return None
        return x["dc:title"]
    
    def author_apply(x):
        name_list = []
        for author in x["author"]:
            name_to_append = ""
            if "ce:given-name" in author:
                name_to_append = f"{author['ce:given-name']} {author['ce:surname']}"
            else: 
                name_to_append = author["ce:indexed-name"]
            name_list.append(name_to_append)
        return name_list
    
    def abstracts_apply(x):
        if "dc:description" not in x or x["dc:description"] == None:
            return None
        return x["dc:description"]
    
    def reference_apply(x):
        if x["bibrecord"] == None or x["bibrecord"]["tail"] == None or x["bibrecord"]["tail"]["bibliography"] == None or x["bibrecord"]["tail"]["bibliography"]["reference"] == None:
            return None
        reference_list = []
        temp = x["bibrecord"]["tail"]["bibliography"]["reference"]
        if type(temp) != type([]):
            temp = [temp]
        for ref in temp:
            if "ref-info" not in ref or "refd-itemidlist" not in ref["ref-info"]:
                continue
            if type(ref["ref-info"]["refd-itemidlist"]["itemid"]) == type([]):
                for j in ref["ref-info"]["refd-itemidlist"]["itemid"]:
                    if "@idtype" in j and j["@idtype"] == "SGR":
                        reference_list.append(j["$"])
            else:
                if "@idtype" in ref["ref-info"]["refd-itemidlist"]["itemid"] and ref["ref-info"]["refd-itemidlist"]["itemid"]["@idtype"] == "SGR":
                    reference_list.append(ref["ref-info"]["refd-itemidlist"]["itemid"]["$"])
        if len(reference_list) == 0:
            return None
        return reference_list
    
    def subject_apply(x):
        subject_list = []
        for subject in x["subject-area"]:
            name = subject["$"]
            code = subject["@code"]
            abbrev = subject["@abbrev"]
            subject_list.append((name, code, abbrev))
        return subject_list

# %%
class PrepareData:
    def __init__(self) -> None:
        self.data = None
        self.data_dir = "./data"
    
    def load_data(self):
        dfs = []
        dir_list = os.listdir("./data")
        cnt = 0
        for i in dir_list:
            if i == ".DS_Store":
                continue

            # Handle too many data
            # if not (i == "2018" or i == "2019"):
            #     continue
            
            sub_dir = os.path.join("./data", i)
            files = os.listdir(sub_dir)
            for f in files:
                if f == ".DS_Store":
                    continue

                file_path = os.path.join(sub_dir, f)
                with open(file_path, "r") as file:
                    json_data = json.load(file)

                row = {key: value for key, value in json_data["abstracts-retrieval-response"].items()}
                row["year"] = int(i)
                dfs.append(pd.DataFrame([row]))
                cnt += 1

        df = pd.concat(dfs, ignore_index=True)
        print("Total data: ", cnt)
        self.data = df

    def save_data(self):
        self.data.to_csv("data.csv", index=False)

    def restructure(self):
        df = self.data.copy()
        
        df["id"] = df["coredata"].apply(utils.id_apply)
        df["title"] = df["coredata"].apply(utils.title_apply)
        df["authors"] = df["authors"].apply(utils.author_apply)
        df["abstracts"] = df["coredata"].apply(utils.abstracts_apply)
        df["references"] = df["item"].apply(utils.reference_apply)
        df["category"] = df["subject-areas"].apply(utils.subject_apply)
        
        # Drop unnecessary columns
        df.drop(columns=["item", "affiliation", "coredata", "idxterms", "language", "authkeywords"], inplace=True)
        
        # Explode subject-areas
        df = df.explode("subject-areas", ignore_index=True)
        
        self.data = df

    def null_count(self):
        for c in self.data.columns:
            print(f"Column {c} have {self.data[c].isnull().sum()} null values")

# %%
data = PrepareData()

# %%
data.load_data()
# Out:
# Total data:  20216

# %%
print(f"Before restructure: {data.data.shape}")
# Out:
# Before restructure: (20216, 9)

# %%
data.data
# Out:
#                                                     item  \
# 0      {'ait:process-info': {'ait:status': {'@state':...
# 1      {'ait:process-info': {'ait:status': {'@state':...
# 2      {'ait:process-info': {'ait:status': {'@state':...
# 3      {'ait:process-info': {'ait:status': {'@state':...
# 4      {'ait:process-info': {'ait:status': {'@state':...
# ...                                                  ...
# 20211  {'ait:process-info': {'ait:status': {'@state':...
# 20212  {'ait:process-info': {'ait:status': {'@state':...
# 20213  {'ait:process-info': {'ait:status': {'@state':...
# 20214  {'ait:process-info': {'ait:status': {'@state':...
# 20215  {'ait:process-info': {'ait:status': {'@state':...
#
#                                              affiliation  \
# 0      {'affiliation-city': 'Bangkok', '@id': '600281...
# 1      [{'affiliation-city': 'Abu Dhabi', '@id': '601...
# 2      [{'affiliation-city': 'Bangkok', '@id': '60002...
# 3      [{'affiliation-city': 'Linkoping', '@id': '600...
# 4      [{'affiliation-city': 'Bangkok', '@id': '60028...
# ...                                                  ...
# 20211  [{'affiliation-city': 'Khon Kaen', '@id': '600...
# 20212  [{'affiliation-city': 'Tokyo', '@id': '6017860...
# 20213  [{'affiliation-city': 'Bangkok', '@id': '60028...
# 20214  {'affiliation-city': 'Bangkok', '@id': '600281...
# 20215  [{'affiliation-city': 'Coventry', '@id': '6011...
#
#                                                 coredata  \
# 0      {'srctype': 'j', 'eid': '2-s2.0-85131139456', ...
# 1      {'srctype': 'j', 'eid': '2-s2.0-85121351780', ...
# 2      {'srctype': 'j', 'eid': '2-s2.0-85131660961', ...
# 3      {'srctype': 'j', 'prism:issueIdentifier': '6',...
# 4      {'srctype': 'j', 'eid': '2-s2.0-85143878806', ...
# ...                                                  ...
# 20211  {'srctype': 'k', 'eid': '2-s2.0-85063382127', ...
# 20212  {'srctype': 'j', 'eid': '2-s2.0-85047370082', ...
# 20213  {'srctype': 'j', 'eid': '2-s2.0-85042389729', ...
# 20214  {'srctype': 'j', 'eid': '2-s2.0-85055194236', ...
# 20215  {'srctype': 'j', 'eid': '2-s2.0-85041549068', ...
#
#                                                 idxterms  \
# 0                                                   None
# 1      {'mainterm': [{'$': 'COVID-19', '@weight': 'a'...
# 2                                                   None
# 3      {'mainterm': [{'$': 'Anisotropic strain', '@we...
# 4                                                   None
# ...                                                  ...
# 20211  {'mainterm': [{'$': 'Actual evapotranspiration...
# 20212  {'mainterm': [{'$': 'Carcinoma, Hepatocellular...
# 20213                                               None
# 20214                                               None
# 20215                                               None
#
#                    language  \
# 0      {'@xml:lang': 'eng'}
# 1      {'@xml:lang': 'eng'}
# 2      {'@xml:lang': 'eng'}
# 3      {'@xml:lang': 'eng'}
# 4      {'@xml:lang': 'eng'}
# ...                     ...
# 20211  {'@xml:lang': 'eng'}
# 20212  {'@xml:lang': 'eng'}
# 20213  {'@xml:lang': 'eng'}
# 20214  {'@xml:lang': 'eng'}
# 20215  {'@xml:lang': 'eng'}
#
#                                             authkeywords  \
# 0      {'author-keyword': [{'@_fa': 'true', '$': 'Ant...
# 1      {'author-keyword': [{'@_fa': 'true', '$': 'car...
# 2      {'author-keyword': [{'@_fa': 'true', '$': 'Alz...
# 3                                                   None
# 4      {'author-keyword': [{'@_fa': 'true', '$': 'Bra...
# ...                                                  ...
# 20211  {'author-keyword': [{'@_fa': 'true', '$': 'Act...
# 20212                                               None
# 20213  {'author-keyword': [{'@_fa': 'true', '$': 'Mot...
# 20214  {'author-keyword': [{'@_fa': 'true', '$': 'Can...
# 20215                                               None
#
#                                            subject-areas  \
# 0      {'subject-area': [{'@_fa': 'true', '$': 'Food ...
# 1      {'subject-area': [{'@_fa': 'true', '$': 'Surge...
# 2      {'subject-area': [{'@_fa': 'true', '$': 'Neuro...
# 3      {'subject-area': [{'@_fa': 'true', '$': 'Physi...
# 4      {'subject-area': [{'@_fa': 'true', '$': 'Physi...
# ...                                                  ...
# 20211  {'subject-area': [{'@_fa': 'true', '$': 'Artif...
# 20212  {'subject-area': [{'@_fa': 'true', '$': 'Multi...
# 20213  {'subject-area': [{'@_fa': 'true', '$': 'Medic...
# 20214  {'subject-area': [{'@_fa': 'true', '$': 'Veter...
# 20215  {'subject-area': [{'@_fa': 'true', '$': 'Econo...
#
#                                                  authors  year
# 0      {'author': [{'ce:given-name': 'Sureerat', 'pre...  2022
# 1      {'author': [{'ce:given-name': 'Abhijit V.', 'p...  2022
# 2      {'author': [{'ce:given-name': 'Solaphat', 'pre...  2022
# 3      {'author': [{'ce:given-name': 'Erik', 'preferr...  2022
# 4      {'author': [{'ce:given-name': 'Kunanya', 'pref...  2022
# ...                                                  ...   ...
# 20211  {'author': [{'ce:given-name': 'Panath', 'prefe...  2018
# 20212  {'author': [{'ce:given-name': 'Hiromi', 'prefe...  2018
# 20213  {'author': [{'ce:given-name': 'Sirinuch', 'pre...  2018
# 20214  {'author': [{'ce:given-name': 'Chutamas', 'pre...  2018
# 20215  {'author': [{'ce:given-name': 'Warn N.', 'pref...  2018
#
# [20216 rows x 9 columns]

# %%
data.restructure()

# %%
print(f"After restructure: {data.data.shape}")
# Out:
# After restructure: (50064, 7)

# %%
data.data
# Out:
#                                   subject-areas  \
# 0                    (Food Science, 1106, AGRI)
# 1                      (Physiology, 1314, BIOC)
# 2      (Animal Science and Zoology, 1103, AGRI)
# 3                        (Genetics, 1311, BIOC)
# 4                (Veterinary (all), 3400, VETE)
# ...                                         ...
# 50059     (Artificial Intelligence, 1702, COMP)
# 50060           (Multidisciplinary, 1000, MULT)
# 50061              (Medicine (all), 2700, MEDI)
# 50062            (Veterinary (all), 3400, VETE)
# 50063  (Economics and Econometrics, 2002, ECON)
#
#                                                  authors  year           id  \
# 0      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 1      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 2      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 3      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 4      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# ...                                                  ...   ...          ...
# 50059  [Panath Jermthaisong, Sununtha Kingpaiboon, Pe...  2018  85063382127
# 50060  [Hiromi Sawai, Nao Nishida, Seik-Soon Khor, Ma...  2018  85047370082
# 50061  [Sirinuch Utarapichat, Wasuwat Kitisomprayoonkul]  2018  85042389729
# 50062  [Chutamas Benjanirut, Chanakarn Wongsangchan, ...  2018  85055194236
# 50063  [Warn N. Lekfuangfu, Nattavudh Powdthavee, Nel...  2018  85041549068
#
#                                                    title  \
# 0      Microencapsulated basil oil (Ocimum basilicum ...
# 1      Microencapsulated basil oil (Ocimum basilicum ...
# 2      Microencapsulated basil oil (Ocimum basilicum ...
# 3      Microencapsulated basil oil (Ocimum basilicum ...
# 4      Microencapsulated basil oil (Ocimum basilicum ...
# ...                                                  ...
# 50059  Estimating actual evapotranspiration from NDVI...
# 50060  Genome-wide association study identified new s...
# 50061  Effects of transcranial direct current stimula...
# 50062  Prevalence and risk factors for canine cogniti...
# 50063  Locus of Control and its Intergenerational Imp...
#
#                                                abstracts  \
# 0      Objective: Microencapsulation is a technique t...
# 1      Objective: Microencapsulation is a technique t...
# 2      Objective: Microencapsulation is a technique t...
# 3      Objective: Microencapsulation is a technique t...
# 4      Objective: Microencapsulation is a technique t...
# ...                                                  ...
# 50059  Evapotranspiration (ET) is the sum of evaporat...
# 50060  We have performed a genome-wide association st...
# 50061  Background: Anodal transcranial direct current...
# 50062  Canine cognitive dysfunction syndrome (CDS) is...
# 50063  This article builds upon Cunha's (2015) subjec...
#
#                                               references
# 0      [85039040394, 85050697915, 84920164411, 849664...
# 1      [85039040394, 85050697915, 84920164411, 849664...
# 2      [85039040394, 85050697915, 84920164411, 849664...
# 3      [85039040394, 85050697915, 84920164411, 849664...
# 4      [85039040394, 85050697915, 84920164411, 849664...
# ...                                                  ...
# 50059  [0003491818, 79952741157, 0028978678, 00247710...
# 50060  [84947346338, 0033935745, 14944385553, 0035467...
# 50061  [33947494560, 33745243839, 36849022625, 751491...
# 50062  [59649128451, 0035379688, 84860848937, 8505515...
# 50063  [84917366795, 84958792377, 81155145322, 000186...
#
# [50064 rows x 7 columns]

# %%
data.data.sample(5)
# Out:
#                                  subject-areas  \
# 14506               (Anthropology, 3314, SOCI)
# 41115     (Mechanical Engineering, 2210, ENGI)
# 5345      (Mechanics of Materials, 2211, ENGI)
# 25818  (Environmental Engineering, 2305, ENVI)
# 12753    (Health (social science), 3306, SOCI)
#
#                                                  authors  year           id  \
# 14506  [Sureenate Jaratjarungkiat, Kyung-Eun Park, Ni...  2023  85170245185
# 41115       [Narunchara Phurahong, Nantana Jiratumnukul]  2020  85087031013
# 5345   [Jadetapong Klahan, Gamolwan Tumcharern, Mongk...  2022  85142168042
# 25818  [Soklida Hong, Thunyalux Ratpukdi, Bunleu Sung...  2019  85060065951
# 12753  [Khursheed Ahmad Shiekh, Thitirat Luanglaor, N...  2023  85146791299
#
#                                                    title  \
# 14506  The Grammaticalization of the Copulas /pēn/ an...
# 41115  Preparation and characterization of surface-mo...
# 5345   Extraction-free techniques for sensitive detec...
# 25818  A sustainable solution for removal of glutaral...
# 12753  Antioxidants and Quality Changes of Thermally ...
#
#                                                abstracts  \
# 14506  The present study has two main aims: 1) to con...
# 41115  Nanocellulose fibers (NCF) is a renewable biod...
# 5345   Fuel adulteration and cross-contamination lead...
# 25818  Glutaraldehyde (GA) is the most common biocide...
# 12753  Purple corn kernels were subjected to boiling ...
#
#                                               references
# 14506  [85170222908, 85170267186, 85170267186, 851702...
# 41115  [85042631554, 85101425564, 85034047986, 849227...
# 5345   [85142146418, 85136680439, 85142176141, 338473...
# 25818  [0003425384, 85041708127, 40549094633, 8504781...
# 12753  [85118807411, 84946491882, 84907814100, 850473...

# %%
data.null_count()
# Out:
# Column subject-areas have 0 null values
# Column authors have 0 null values
# Column year have 0 null values
# Column id have 0 null values
# Column title have 2 null values
# Column abstracts have 1251 null values
# Column references have 899 null values

# %%
data.data.dropna(subset=["abstracts"], inplace=True)
data.data.dropna(subset=["references"], inplace=True)
data.data.dropna(subset=["title"], inplace=True)

data.data.shape
# Out:
# (48227, 7)

# %%
data.data
# Out:
#                                   subject-areas  \
# 0                    (Food Science, 1106, AGRI)
# 1                      (Physiology, 1314, BIOC)
# 2      (Animal Science and Zoology, 1103, AGRI)
# 3                        (Genetics, 1311, BIOC)
# 4                (Veterinary (all), 3400, VETE)
# ...                                         ...
# 50059     (Artificial Intelligence, 1702, COMP)
# 50060           (Multidisciplinary, 1000, MULT)
# 50061              (Medicine (all), 2700, MEDI)
# 50062            (Veterinary (all), 3400, VETE)
# 50063  (Economics and Econometrics, 2002, ECON)
#
#                                                  authors  year           id  \
# 0      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 1      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 2      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 3      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# 4      [Sureerat Thuekeaw, Kris Angkanaporn, Chackrit...  2022  85131139456
# ...                                                  ...   ...          ...
# 50059  [Panath Jermthaisong, Sununtha Kingpaiboon, Pe...  2018  85063382127
# 50060  [Hiromi Sawai, Nao Nishida, Seik-Soon Khor, Ma...  2018  85047370082
# 50061  [Sirinuch Utarapichat, Wasuwat Kitisomprayoonkul]  2018  85042389729
# 50062  [Chutamas Benjanirut, Chanakarn Wongsangchan, ...  2018  85055194236
# 50063  [Warn N. Lekfuangfu, Nattavudh Powdthavee, Nel...  2018  85041549068
#
#                                                    title  \
# 0      Microencapsulated basil oil (Ocimum basilicum ...
# 1      Microencapsulated basil oil (Ocimum basilicum ...
# 2      Microencapsulated basil oil (Ocimum basilicum ...
# 3      Microencapsulated basil oil (Ocimum basilicum ...
# 4      Microencapsulated basil oil (Ocimum basilicum ...
# ...                                                  ...
# 50059  Estimating actual evapotranspiration from NDVI...
# 50060  Genome-wide association study identified new s...
# 50061  Effects of transcranial direct current stimula...
# 50062  Prevalence and risk factors for canine cogniti...
# 50063  Locus of Control and its Intergenerational Imp...
#
#                                                abstracts  \
# 0      Objective: Microencapsulation is a technique t...
# 1      Objective: Microencapsulation is a technique t...
# 2      Objective: Microencapsulation is a technique t...
# 3      Objective: Microencapsulation is a technique t...
# 4      Objective: Microencapsulation is a technique t...
# ...                                                  ...
# 50059  Evapotranspiration (ET) is the sum of evaporat...
# 50060  We have performed a genome-wide association st...
# 50061  Background: Anodal transcranial direct current...
# 50062  Canine cognitive dysfunction syndrome (CDS) is...
# 50063  This article builds upon Cunha's (2015) subjec...
#
#                                               references
# 0      [85039040394, 85050697915, 84920164411, 849664...
# 1      [85039040394, 85050697915, 84920164411, 849664...
# 2      [85039040394, 85050697915, 84920164411, 849664...
# 3      [85039040394, 85050697915, 84920164411, 849664...
# 4      [85039040394, 85050697915, 84920164411, 849664...
# ...                                                  ...
# 50059  [0003491818, 79952741157, 0028978678, 00247710...
# 50060  [84947346338, 0033935745, 14944385553, 0035467...
# 50061  [33947494560, 33745243839, 36849022625, 751491...
# 50062  [59649128451, 0035379688, 84860848937, 8505515...
# 50063  [84917366795, 84958792377, 81155145322, 000186...
#
# [48227 rows x 7 columns]

# %%
data.save_data()
