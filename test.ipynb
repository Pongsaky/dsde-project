# %%
import requests
import json
api_key = '745ea004c1ead1f4cb79eef4123af7c1'

# %%
class ScopusScraping(object):
    
    def __init__(self, apikey=None):
        self.apikey = apikey
        
    def add_key(self, apikey):
        self.apikey = apikey
        
    def retrieve_abstract(self,  scopus_id):
        abstract_url = f'https://api.elsevier.com/content/abstract/scopus_id/{scopus_id}'
        abstract_headers = {
            'Authorization' : "Bearer 745ea004c1ead1f4cb79eef4123af7c1",
            'X-ELS-APIKey': self.api_key,
            'Accept': 'application/json',
        }

        params = {
            'query': 'ALL',  # Example: Search for articles with "machine learning" in the title
            'count': 5,                          # Number of results
            'start': 0,                           # Starting index
            'apikey': self.api_key,
            'date' : 2017,
            
        }

        # Perform the abstract retrieval
        abstract_response = requests.get(abstract_url, headers=abstract_headers, params=params)

        # Handle the response
        if abstract_response.status_code == 200:
            abstract_data = abstract_response.json()
            print("Abstract Details:")
            print(json.dumps(abstract_data, indent=4))  # Pretty-print the JSON data
        else:
            print(f"Error: {abstract_response.status_code}, {abstract_response.text}")

# %%
base_url = 'https://api.elsevier.com/content/search/scopus'

# Query parameters
params = {
    'query': 'ALL',  # Example: Search for articles with "machine learning" in the title
    'count': 5,                          # Number of results
    'start': 0,                           # Starting index
    'apikey': api_key,
    'date' : 2017,
    
}

# Headers
headers = {
    'X-ELS-APIKey': api_key,
    'Accept': 'application/json'  # JSON response
}

# Make the GET request
response = requests.get(base_url, headers=headers, params=params)

# Check response status and print results
if response.status_code == 200:
    data = response.json()
    data_json = json.dumps(data, indent=4) # Process the JSON response
    print(data_json)
    # with open("kuy.json", "w") as outfile:
    #     outfile.write(data_json)
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# {
#     "search-results": {
#         "opensearch:totalResults": "3242224",
#         "opensearch:startIndex": "0",
#         "opensearch:itemsPerPage": "5",
#         "opensearch:Query": {
#             "@role": "request",
#             "@searchTerms": "ALL",
#             "@startPage": "0"
#         },
#         "link": [
#             {
#                 "@_fa": "true",
#                 "@ref": "self",
#                 "@href": "https://api.elsevier.com/content/search/scopus?start=0&count=5&query=ALL&apiKey=745ea004c1ead1f4cb79eef4123af7c1&date=2017",
#                 "@type": "application/json"
#             },
#             {
#                 "@_fa": "true",
#                 "@ref": "first",
#                 "@href": "https://api.elsevier.com/content/search/scopus?start=0&count=5&query=ALL&apiKey=745ea004c1ead1f4cb79eef4123af7c1&date=2017",
#                 "@type": "application/json"
#             },
#             {
#                 "@_fa": "true",
#                 "@ref": "next",
#                 "@href": "https://api.elsevier.com/content/search/scopus?start=5&count=5&query=ALL&apiKey=745ea004c1ead1f4cb79eef4123af7c1&date=2017",
#                 "@type": "application/json"
#             },
#             {
#                 "@_fa": "true",
#                 "@ref": "last",
#                 "@href": "https://api.elsevier.com/content/search/scopus?start=4995&count=5&query=ALL&apiKey=745ea004c1ead1f4cb79eef4123af7c1&date=2017",
#                 "@type": "application/json"
#             }
#         ],
#         "entry": [
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/abstract/scopus_id/85207964401"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "author-affiliation",
#                         "@href": "https://api.elsevier.com/content/abstract/scopus_id/85207964401?field=author,affiliation"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus",
#                         "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85207964401&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85207964401&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85207964401",
#                 "dc:identifier": "SCOPUS_ID:85207964401",
#                 "eid": "2-s2.0-85207964401",
#                 "dc:title": "M\u00f6druvallab\u00f3k, AM 132 Fol.: Volume One: Index and Concordance",
#                 "dc:creator": "Arkel-de Leeuw van Weenen A.v.",
#                 "prism:publicationName": "M\u00f6druvallab\u00f3k, AM 132 Fol.: Volume One: Index and Concordance",
#                 "prism:isbn": [
#                     {
#                         "@_fa": "true",
#                         "$": "[9789004647107, 9789004086197]"
#                     }
#                 ],
#                 "prism:pageRange": "1-272",
#                 "prism:coverDate": "2017-12-31",
#                 "prism:coverDisplayDate": "31 December 2017",
#                 "prism:doi": "10.1163/9789004647107",
#                 "citedby-count": "0",
#                 "prism:aggregationType": "Book",
#                 "subtype": "bk",
#                 "subtypeDescription": "Book",
#                 "source-id": "21101256450",
#                 "openaccess": "0",
#                 "openaccessFlag": false
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/abstract/scopus_id/85179929360"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "author-affiliation",
#                         "@href": "https://api.elsevier.com/content/abstract/scopus_id/85179929360?field=author,affiliation"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus",
#                         "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85179929360&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85179929360&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85179929360",
#                 "dc:identifier": "SCOPUS_ID:85179929360",
#                 "eid": "2-s2.0-85179929360",
#                 "dc:title": "Study on mandatory standards of soil and water conservation",
#                 "dc:creator": "Zhu B.",
#                 "prism:publicationName": "Science of Soil and Water Conservation",
#                 "prism:issn": "20962673",
#                 "prism:volume": "15",
#                 "prism:issueIdentifier": "6",
#                 "prism:pageRange": "140-146",
#                 "prism:coverDate": "2017-12-31",
#                 "prism:coverDisplayDate": "31 December 2017",
#                 "prism:doi": "10.16843/j.sswc.2017.06.017",
#                 "citedby-count": "0",
#                 "affiliation": [
#                     {
#                         "@_fa": "true",
#                         "affilname": "Ministry of Water Resources, P.R. China",
#                         "affiliation-city": "Beijing",
#                         "affiliation-country": "China"
#                     },
#                     {
#                         "@_fa": "true",
#                         "affilname": "China Institute of Water Resources and Hydropower Research",
#                         "affiliation-city": "Beijing",
#                         "affiliation-country": "China"
#                     }
#                 ],
#                 "prism:aggregationType": "Journal",
#                 "subtype": "ar",
#                 "subtypeDescription": "Article",
#                 "source-id": "21101037289",
#                 "openaccess": "0",
#                 "openaccessFlag": false
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/abstract/scopus_id/85168358483"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "author-affiliation",
#                         "@href": "https://api.elsevier.com/content/abstract/scopus_id/85168358483?field=author,affiliation"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus",
#                         "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168358483&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85168358483&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85168358483",
#                 "dc:identifier": "SCOPUS_ID:85168358483",
#                 "eid": "2-s2.0-85168358483",
#                 "dc:title": "Spectrums of thought in gesture: Using gestures to analyze concepts in philosophy",
#                 "dc:creator": "Paul Stevens M.",
#                 "prism:publicationName": "Pragmatics and Cognition",
#                 "prism:issn": "09290907",
#                 "prism:eIssn": "15699943",
#                 "prism:volume": "24",
#                 "prism:issueIdentifier": "3",
#                 "prism:pageRange": "441-473",
#                 "prism:coverDate": "2017-12-31",
#                 "prism:coverDisplayDate": "31 December 2017",
#                 "prism:doi": "10.1075/pc.17024.ste",
#                 "citedby-count": "2",
#                 "affiliation": [
#                     {
#                         "@_fa": "true",
#                         "affilname": "University of Nottingham Ningbo China",
#                         "affiliation-city": "Ningbo",
#                         "affiliation-country": "China"
#                     }
#                 ],
#                 "prism:aggregationType": "Journal",
#                 "subtype": "ar",
#                 "subtypeDescription": "Article",
#                 "source-id": "145567",
#                 "openaccess": "0",
#                 "openaccessFlag": false
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/abstract/scopus_id/85168355171"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "author-affiliation",
#                         "@href": "https://api.elsevier.com/content/abstract/scopus_id/85168355171?field=author,affiliation"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus",
#                         "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168355171&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85168355171&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85168355171",
#                 "dc:identifier": "SCOPUS_ID:85168355171",
#                 "eid": "2-s2.0-85168355171",
#                 "dc:title": "Cognitive processing of scalar implicatures with Chinese gradable adjectives",
#                 "dc:creator": "Liu S.",
#                 "prism:publicationName": "Pragmatics and Cognition",
#                 "prism:issn": "09290907",
#                 "prism:eIssn": "15699943",
#                 "prism:volume": "24",
#                 "prism:issueIdentifier": "3",
#                 "prism:pageRange": "373-403",
#                 "prism:coverDate": "2017-12-31",
#                 "prism:coverDisplayDate": "31 December 2017",
#                 "prism:doi": "10.1075/pc.17036.liu",
#                 "citedby-count": "0",
#                 "affiliation": [
#                     {
#                         "@_fa": "true",
#                         "affilname": "Lanzhou University",
#                         "affiliation-city": "Lanzhou",
#                         "affiliation-country": "China"
#                     }
#                 ],
#                 "prism:aggregationType": "Journal",
#                 "subtype": "ar",
#                 "subtypeDescription": "Article",
#                 "source-id": "145567",
#                 "openaccess": "0",
#                 "openaccessFlag": false
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/abstract/scopus_id/85160654985"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "author-affiliation",
#                         "@href": "https://api.elsevier.com/content/abstract/scopus_id/85160654985?field=author,affiliation"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus",
#                         "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85160654985&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85160654985&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85160654985",
#                 "dc:identifier": "SCOPUS_ID:85160654985",
#                 "eid": "2-s2.0-85160654985",
#                 "dc:title": "Solid Waste Management Awareness, Attitude, and Practices in a Philippine Catholic Higher Education Institution",
#                 "dc:creator": "Madrigal D.V.",
#                 "prism:publicationName": "Recoletos Multidisciplinary Research Journal",
#                 "prism:issn": "24231398",
#                 "prism:eIssn": "24083755",
#                 "prism:volume": "5",
#                 "prism:issueIdentifier": "2",
#                 "prism:pageRange": "43-57",
#                 "prism:coverDate": "2017-12-31",
#                 "prism:coverDisplayDate": "31 December 2017",
#                 "prism:doi": "10.32871/rmrj1705.02.04",
#                 "citedby-count": "10",
#                 "affiliation": [
#                     {
#                         "@_fa": "true",
#                         "affilname": "University of Negros Occidental- Recoletos",
#                         "affiliation-city": "Bacolod",
#                         "affiliation-country": "Philippines"
#                     }
#                 ],
#                 "prism:aggregationType": "Journal",
#                 "subtype": "ar",
#                 "subtypeDescription": "Article",
#                 "source-id": "21101105288",
#                 "openaccess": "1",
#                 "openaccessFlag": true,
#                 "freetoread": {
#                     "value": [
#                         {
#                             "$": "all"
#                         },
#                         {
#                             "$": "publisherfullgold"
#                         }
#                     ]
#                 },
#                 "freetoreadLabel": {
#                     "value": [
#                         {
#                             "$": "All Open Access"
#                         },
#                         {
#                             "$": "Gold"
#                         }
#                     ]
#                 }
#             }
#         ]
#     }
# }

# %%
scopus_id = "85207964401"
abstract_url = f'https://api.elsevier.com/content/abstract/scopus_id/{scopus_id}'

# Headers for the abstract retrieval
abstract_headers = {
    'Authorization' : "Bearer 745ea004c1ead1f4cb79eef4123af7c1",
    'X-ELS-APIKey': api_key,
    'Accept': 'application/json',
}

params = {
    'query': 'ALL',  # Example: Search for articles with "machine learning" in the title
    'count': 5,                          # Number of results
    'start': 0,                           # Starting index
    'apikey': api_key,
    'date' : 2017,
    
}

# Perform the abstract retrieval
abstract_response = requests.get(abstract_url, headers=abstract_headers, params=params)

# Handle the response
if abstract_response.status_code == 200:
    abstract_data = abstract_response.json()
    print("Abstract Details:")
    print(json.dumps(abstract_data, indent=4))  # Pretty-print the JSON data
else:
    print(f"Error: {abstract_response.status_code}, {abstract_response.text}")
# Out:
# Abstract Details:
# {
#     "abstracts-retrieval-response": {
#         "item": {
#             "ait:process-info": {
#                 "ait:status": {
#                     "@state": "new",
#                     "@type": "core",
#                     "@stage": "S300"
#                 },
#                 "ait:date-delivered": {
#                     "@day": "06",
#                     "@timestamp": "2024-11-06T04:59:02.000002-05:00",
#                     "@year": "2024",
#                     "@month": "11"
#                 },
#                 "ait:date-sort": {
#                     "@day": "31",
#                     "@year": "2017",
#                     "@month": "12"
#                 }
#             },
#             "bibrecord": {
#                 "head": {
#                     "author-group": {
#                         "author": [
#                             {
#                                 "ce:given-name": "Andrea van",
#                                 "preferred-name": {
#                                     "ce:given-name": "Andrea van",
#                                     "ce:initials": "A.v.",
#                                     "ce:surname": "Arkel-de Leeuw van Weenen",
#                                     "ce:indexed-name": "Arkel-de Leeuw van Weenen A.v."
#                                 },
#                                 "@author-instance-id": "OB2BibRecID-959969121-c67a5b7d8d8de90e2e3084794f306db6-1",
#                                 "@seq": "1",
#                                 "ce:initials": "A.",
#                                 "@_fa": "true",
#                                 "@type": "auth",
#                                 "ce:surname": "Arkel-de Leeuw van Weenen",
#                                 "@auid": "59391172400",
#                                 "ce:indexed-name": "Arkel-de Leeuw van Weenen A."
#                             }
#                         ]
#                     },
#                     "citation-title": "M\u00f6druvallab\u00f3k, AM 132 Fol.: Volume One: Index and Concordance",
#                     "abstracts": "\u00a9 1987 by E. J. Brill, Leiden, The Netherlands. All rights reserved.The ultimate goal of the Modruvallabok Project is a description of the language in Modruvallabok. Publication of a survey of the orthography and morphology is planned for the not too distant future. It was deemed, however, to be in the interest of Old Icelandic research that the concordance and index should be made available to the public as soon as possible. As an index or concordance to an -practically -unavailable text is an absurdity, it was decided to include the transcription of the text as well. Of course, the publication will come into its own only when more texts have been treated in the same way and comparison, both synchronic and diachronic, has become possible. It is hoped, however, that the study of Old Icelandic will already now profit from this work. Users are kindly requested to forward details to the publisher of any errors they may discover in the text and index.",
#                     "correspondence": {
#                         "person": {
#                             "ce:given-name": "Andrea van",
#                             "@author-instance-id": "OB2BibRecID-959969121-6756e1320526e0dd5a16a21edbe562b1-1",
#                             "ce:initials": "A.",
#                             "ce:surname": "Arkel-de Leeuw van Weenen",
#                             "ce:indexed-name": "Arkel-de Leeuw van Weenen A."
#                         }
#                     },
#                     "citation-info": {
#                         "citation-type": {
#                             "@code": "bk"
#                         },
#                         "citation-language": {
#                             "@language": "English",
#                             "@xml:lang": "eng"
#                         },
#                         "abstract-language": {
#                             "@language": "English",
#                             "@xml:lang": "eng"
#                         }
#                     },
#                     "source": {
#                         "sourcetitle-abbrev": "M\u00f6druvallab\u00f3k, AM 132 Fol.: Volume One: Index and Concord.",
#                         "website": {
#                             "ce:e-address": {
#                                 "$": "https://brill.com/display/title/36436",
#                                 "@type": "email"
#                             }
#                         },
#                         "@country": "usa",
#                         "translated-sourcetitle": {
#                             "@xml:lang": "eng"
#                         },
#                         "volisspag": {
#                             "pagerange": {
#                                 "@first": "1",
#                                 "@last": "272"
#                             }
#                         },
#                         "@type": "b",
#                         "publicationyear": {
#                             "@first": "2017"
#                         },
#                         "isbn": [
#                             {
#                                 "@level": "volume",
#                                 "$": "9789004647107",
#                                 "@type": "electronic",
#                                 "@length": "13"
#                             },
#                             {
#                                 "@level": "volume",
#                                 "$": "9789004086197",
#                                 "@type": "print",
#                                 "@length": "13"
#                             }
#                         ],
#                         "publisher": {
#                             "publishername": "Brill"
#                         },
#                         "sourcetitle": "M\u00f6druvallab\u00f3k, AM 132 Fol.: Volume One: Index and Concordance",
#                         "@srcid": "21101256450",
#                         "publicationdate": {
#                             "month": "12",
#                             "year": "2017",
#                             "date-text": {
#                                 "@xfab-added": "true",
#                                 "$": "31 December 2017"
#                             },
#                             "day": "31"
#                         }
#                     },
#                     "enhancement": {
#                         "classificationgroup": {
#                             "classifications": [
#                                 {
#                                     "@type": "ASJC",
#                                     "classification": [
#                                         {
#                                             "$": "1200"
#                                         },
#                                         {
#                                             "$": "3300"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "@type": "SUBJABBR",
#                                     "classification": [
#                                         {
#                                             "$": "ARTS"
#                                         },
#                                         {
#                                             "$": "SOCI"
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     }
#                 },
#                 "item-info": {
#                     "copyright": {
#                         "$": "Copyright 2024 Elsevier B.V., All rights reserved.",
#                         "@type": "Elsevier"
#                     },
#                     "dbcollection": [
#                         {
#                             "$": "SCOPUS"
#                         },
#                         {
#                             "$": "SNBOOK"
#                         },
#                         {
#                             "$": "Scopusbase"
#                         }
#                     ],
#                     "history": {
#                         "date-created": {
#                             "@day": "05",
#                             "@timestamp": "BST 14:40:27",
#                             "@year": "2024",
#                             "@month": "11"
#                         }
#                     },
#                     "itemidlist": {
#                         "itemid": [
#                             {
#                                 "$": "645643589",
#                                 "@idtype": "PUI"
#                             },
#                             {
#                                 "$": "959969121",
#                                 "@idtype": "CAR-ID"
#                             },
#                             {
#                                 "$": "20244377606",
#                                 "@idtype": "SCOPUS"
#                             },
#                             {
#                                 "$": "2024510969",
#                                 "@idtype": "SNBOOK"
#                             },
#                             {
#                                 "$": "959969121#353778207",
#                                 "@idtype": "SRC-OCC-ID"
#                             },
#                             {
#                                 "$": "20242000481326",
#                                 "@idtype": "TPB-ID"
#                             },
#                             {
#                                 "$": "20241004578214",
#                                 "@idtype": "VTW-CAR-ID"
#                             },
#                             {
#                                 "$": "85207964401",
#                                 "@idtype": "SCP"
#                             },
#                             {
#                                 "$": "85207964401",
#                                 "@idtype": "SGR"
#                             }
#                         ],
#                         "ce:doi": "10.1163/9789004647107"
#                     }
#                 },
#                 "tail": null
#             }
#         },
#         "coredata": {
#             "srctype": "b",
#             "eid": "2-s2.0-85207964401",
#             "dc:description": "The ultimate goal of the Modruvallabok Project is a description of the language in Modruvallabok. Publication of a survey of the orthography and morphology is planned for the not too distant future. It was deemed, however, to be in the interest of Old Icelandic research that the concordance and index should be made available to the public as soon as possible. As an index or concordance to an -practically -unavailable text is an absurdity, it was decided to include the transcription of the text as well. Of course, the publication will come into its own only when more texts have been treated in the same way and comparison, both synchronic and diachronic, has become possible. It is hoped, however, that the study of Old Icelandic will already now profit from this work. Users are kindly requested to forward details to the publisher of any errors they may discover in the text and index.",
#             "prism:coverDate": "2017-12-31",
#             "prism:aggregationType": "Book",
#             "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85207964401",
#             "subtypeDescription": "Book",
#             "dc:creator": {
#                 "author": [
#                     {
#                         "ce:given-name": "Andrea van",
#                         "preferred-name": {
#                             "ce:given-name": "Andrea van",
#                             "ce:initials": "A.v.",
#                             "ce:surname": "Arkel-de Leeuw van Weenen",
#                             "ce:indexed-name": "Arkel-de Leeuw van Weenen A.v."
#                         },
#                         "@seq": "1",
#                         "ce:initials": "A.",
#                         "@_fa": "true",
#                         "ce:surname": "Arkel-de Leeuw van Weenen",
#                         "@auid": "59391172400",
#                         "author-url": "https://api.elsevier.com/content/author/author_id/59391172400",
#                         "ce:indexed-name": "Arkel-de Leeuw van Weenen A."
#                     }
#                 ]
#             },
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@rel": "self",
#                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85207964401"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@rel": "scopus",
#                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85207964401&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@rel": "scopus-citedby",
#                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85207964401&origin=inward"
#                 }
#             ],
#             "prism:isbn": [
#                 {
#                     "$": "9789004647107"
#                 },
#                 {
#                     "$": "9789004086197"
#                 }
#             ],
#             "prism:publicationName": "M\u00f6druvallab\u00f3k, AM 132 Fol.: Volume One: Index and Concordance",
#             "source-id": "21101256450",
#             "citedby-count": "0",
#             "subtype": "bk",
#             "prism:pageRange": "1-272",
#             "dc:title": "M\u00f6druvallab\u00f3k, AM 132 Fol.: Volume One: Index and Concordance",
#             "prism:endingPage": "272",
#             "openaccess": "0",
#             "openaccessFlag": "false",
#             "prism:doi": "10.1163/9789004647107",
#             "prism:startingPage": "1",
#             "publishercopyright": "\u00a9 1987 by E. J. Brill, Leiden, The Netherlands. All rights reserved.",
#             "dc:identifier": "SCOPUS_ID:85207964401",
#             "dc:publisher": "Brill"
#         },
#         "idxterms": null,
#         "language": {
#             "@xml:lang": "eng"
#         },
#         "authkeywords": null,
#         "subject-areas": {
#             "subject-area": [
#                 {
#                     "@_fa": "true",
#                     "$": "Arts and Humanities (all)",
#                     "@code": "1200",
#                     "@abbrev": "ARTS"
#                 },
#                 {
#                     "@_fa": "true",
#                     "$": "Social Sciences (all)",
#                     "@code": "3300",
#                     "@abbrev": "SOCI"
#                 }
#             ]
#         },
#         "authors": {
#             "author": [
#                 {
#                     "ce:given-name": "Andrea van",
#                     "preferred-name": {
#                         "ce:given-name": "Andrea van",
#                         "ce:initials": "A.v.",
#                         "ce:surname": "Arkel-de Leeuw van Weenen",
#                         "ce:indexed-name": "Arkel-de Leeuw van Weenen A.v."
#                     },
#                     "@seq": "1",
#                     "ce:initials": "A.",
#                     "@_fa": "true",
#                     "ce:surname": "Arkel-de Leeuw van Weenen",
#                     "@auid": "59391172400",
#                     "author-url": "https://api.elsevier.com/content/author/author_id/59391172400",
#                     "ce:indexed-name": "Arkel-de Leeuw van Weenen A."
#                 }
#             ]
#         }
#     }
# }
