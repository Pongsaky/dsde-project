# %%
import pandas as pd
import json
import os

# %% [markdown]
# # Class for Restructuring

# %% [markdown]
# #### Note for Restructuring
#
# There are 7 columns.
#
# | Column         | Description                         |
# |----------------|-------------------------------------|
# | id             | Unique identifier                   |
# | title          | Title of research                   |
# | category       | tuple (code, subject name, abbrev)  |
# | authors        | List of authors                     |
# | year           | Year of publication                 |
# | abstracts      | Abstract text                       |
# | references     | List of references (id of research) |

# %%
class utils:
    def id_apply(x):
        return x["prism:url"].split("/")[-1]
    
    def title_apply(x):
        if "dc:title" not in x or x["dc:title"] == None:
            return None
        return x["dc:title"]
    
    def author_apply(x):
        # name_list = []
        combine_name = ""
        for author in x["author"]:
            name_to_append = ""
            if "ce:given-name" in author:
                name_to_append = f"{author['ce:given-name']} {author['ce:surname']}"
            else: 
                name_to_append = author["ce:indexed-name"]
            # name_list.append(name_to_append)
            combine_name += name_to_append + ", "
        return combine_name
    
    def abstracts_apply(x):
        if "dc:description" not in x or x["dc:description"] == None:
            return None
        return x["dc:description"]
    
    def reference_apply(x):
        if x["bibrecord"] == None or x["bibrecord"]["tail"] == None or x["bibrecord"]["tail"]["bibliography"] == None or x["bibrecord"]["tail"]["bibliography"]["reference"] == None:
            return None
        reference_list = []
        temp = x["bibrecord"]["tail"]["bibliography"]["reference"]
        if type(temp) != type([]):
            temp = [temp]
        for ref in temp:
            if "ref-info" not in ref or "refd-itemidlist" not in ref["ref-info"]:
                continue
            if type(ref["ref-info"]["refd-itemidlist"]["itemid"]) == type([]):
                for j in ref["ref-info"]["refd-itemidlist"]["itemid"]:
                    if "@idtype" in j and j["@idtype"] == "SGR":
                        reference_list.append(j["$"])
            else:
                if "@idtype" in ref["ref-info"]["refd-itemidlist"]["itemid"] and ref["ref-info"]["refd-itemidlist"]["itemid"]["@idtype"] == "SGR":
                    reference_list.append(ref["ref-info"]["refd-itemidlist"]["itemid"]["$"])
        if len(reference_list) == 0:
            return None
        return reference_list
    
    def subject_apply(x):
        subject_list = []
        for subject in x["subject-area"]:
            name = subject["$"]
            code = subject["@code"]
            abbrev = subject["@abbrev"]
            subject_list.append((name, code, abbrev))
        return subject_list

# %%
class PrepareData:
    def __init__(self) -> None:
        self.data = None
        self.data_dir = "./data"
    
    def load_data(self):
        dfs = []
        dir_list = os.listdir("./data")
        cnt = 0
        for i in dir_list:
            if i == ".DS_Store":
                continue

            # Handle too many data
            # if not (i == "2018" or i == "2019"):
            #     continue
            
            sub_dir = os.path.join("./data", i)
            files = os.listdir(sub_dir)
            for f in files:
                if f == ".DS_Store":
                    continue

                file_path = os.path.join(sub_dir, f)
                with open(file_path, "r") as file:
                    json_data = json.load(file)

                row = {key: value for key, value in json_data["abstracts-retrieval-response"].items()}
                row["year"] = int(i)
                dfs.append(pd.DataFrame([row]))
                cnt += 1

        df = pd.concat(dfs, ignore_index=True)
        print("Total data: ", cnt)
        self.data = df

    def save_data(self, file_name:str):
        if file_name.split(".")[-1] != "csv":
            file_name += ".csv"

        self.data.to_csv(file_name, index=False)

    def restructure(self):
        df = self.data.copy()
        
        df["id"] = df["coredata"].apply(utils.id_apply)
        df["title"] = df["coredata"].apply(utils.title_apply)
        df["authors"] = df["authors"].apply(utils.author_apply)
        df["abstract"] = df["coredata"].apply(utils.abstracts_apply)
        df["references"] = df["item"].apply(utils.reference_apply)
        df["category"] = df["subject-areas"].apply(utils.subject_apply)
        df["source"] = "scopus"
        
        # Drop unnecessary columns
        df.drop(columns=["item", "affiliation", "coredata", "idxterms", "language", "authkeywords", "subject-areas"], inplace=True)
        
        # Explode subject-areas
        # df = df.explode("category", ignore_index=True)
        
        self.data = df

    def null_count(self):
        for c in self.data.columns:
            print(f"Column {c} have {self.data[c].isnull().sum()} null values")

# %%
data = PrepareData()

# %%
data.load_data()
# Out:
# Total data:  20216

# %%
print(f"Before restructure: {data.data.shape}")
# Out:
# Before restructure: (20216, 9)

# %%
data.data
# Out:
#                                                     item  \
# 0      {'ait:process-info': {'ait:status': {'@state':...
# 1      {'ait:process-info': {'ait:status': {'@state':...
# 2      {'ait:process-info': {'ait:status': {'@state':...
# 3      {'ait:process-info': {'ait:status': {'@state':...
# 4      {'ait:process-info': {'ait:status': {'@state':...
# ...                                                  ...
# 20211  {'ait:process-info': {'ait:status': {'@state':...
# 20212  {'ait:process-info': {'ait:status': {'@state':...
# 20213  {'ait:process-info': {'ait:status': {'@state':...
# 20214  {'ait:process-info': {'ait:status': {'@state':...
# 20215  {'ait:process-info': {'ait:status': {'@state':...
#
#                                              affiliation  \
# 0      {'affiliation-city': 'Bangkok', '@id': '600281...
# 1      [{'affiliation-city': 'Abu Dhabi', '@id': '601...
# 2      [{'affiliation-city': 'Bangkok', '@id': '60002...
# 3      [{'affiliation-city': 'Linkoping', '@id': '600...
# 4      [{'affiliation-city': 'Bangkok', '@id': '60028...
# ...                                                  ...
# 20211  [{'affiliation-city': 'Khon Kaen', '@id': '600...
# 20212  [{'affiliation-city': 'Tokyo', '@id': '6017860...
# 20213  [{'affiliation-city': 'Bangkok', '@id': '60028...
# 20214  {'affiliation-city': 'Bangkok', '@id': '600281...
# 20215  [{'affiliation-city': 'Coventry', '@id': '6011...
#
#                                                 coredata  \
# 0      {'srctype': 'j', 'eid': '2-s2.0-85131139456', ...
# 1      {'srctype': 'j', 'eid': '2-s2.0-85121351780', ...
# 2      {'srctype': 'j', 'eid': '2-s2.0-85131660961', ...
# 3      {'srctype': 'j', 'prism:issueIdentifier': '6',...
# 4      {'srctype': 'j', 'eid': '2-s2.0-85143878806', ...
# ...                                                  ...
# 20211  {'srctype': 'k', 'eid': '2-s2.0-85063382127', ...
# 20212  {'srctype': 'j', 'eid': '2-s2.0-85047370082', ...
# 20213  {'srctype': 'j', 'eid': '2-s2.0-85042389729', ...
# 20214  {'srctype': 'j', 'eid': '2-s2.0-85055194236', ...
# 20215  {'srctype': 'j', 'eid': '2-s2.0-85041549068', ...
#
#                                                 idxterms  \
# 0                                                   None
# 1      {'mainterm': [{'$': 'COVID-19', '@weight': 'a'...
# 2                                                   None
# 3      {'mainterm': [{'$': 'Anisotropic strain', '@we...
# 4                                                   None
# ...                                                  ...
# 20211  {'mainterm': [{'$': 'Actual evapotranspiration...
# 20212  {'mainterm': [{'$': 'Carcinoma, Hepatocellular...
# 20213                                               None
# 20214                                               None
# 20215                                               None
#
#                    language  \
# 0      {'@xml:lang': 'eng'}
# 1      {'@xml:lang': 'eng'}
# 2      {'@xml:lang': 'eng'}
# 3      {'@xml:lang': 'eng'}
# 4      {'@xml:lang': 'eng'}
# ...                     ...
# 20211  {'@xml:lang': 'eng'}
# 20212  {'@xml:lang': 'eng'}
# 20213  {'@xml:lang': 'eng'}
# 20214  {'@xml:lang': 'eng'}
# 20215  {'@xml:lang': 'eng'}
#
#                                             authkeywords  \
# 0      {'author-keyword': [{'@_fa': 'true', '$': 'Ant...
# 1      {'author-keyword': [{'@_fa': 'true', '$': 'car...
# 2      {'author-keyword': [{'@_fa': 'true', '$': 'Alz...
# 3                                                   None
# 4      {'author-keyword': [{'@_fa': 'true', '$': 'Bra...
# ...                                                  ...
# 20211  {'author-keyword': [{'@_fa': 'true', '$': 'Act...
# 20212                                               None
# 20213  {'author-keyword': [{'@_fa': 'true', '$': 'Mot...
# 20214  {'author-keyword': [{'@_fa': 'true', '$': 'Can...
# 20215                                               None
#
#                                            subject-areas  \
# 0      {'subject-area': [{'@_fa': 'true', '$': 'Food ...
# 1      {'subject-area': [{'@_fa': 'true', '$': 'Surge...
# 2      {'subject-area': [{'@_fa': 'true', '$': 'Neuro...
# 3      {'subject-area': [{'@_fa': 'true', '$': 'Physi...
# 4      {'subject-area': [{'@_fa': 'true', '$': 'Physi...
# ...                                                  ...
# 20211  {'subject-area': [{'@_fa': 'true', '$': 'Artif...
# 20212  {'subject-area': [{'@_fa': 'true', '$': 'Multi...
# 20213  {'subject-area': [{'@_fa': 'true', '$': 'Medic...
# 20214  {'subject-area': [{'@_fa': 'true', '$': 'Veter...
# 20215  {'subject-area': [{'@_fa': 'true', '$': 'Econo...
#
#                                                  authors  year
# 0      {'author': [{'ce:given-name': 'Sureerat', 'pre...  2022
# 1      {'author': [{'ce:given-name': 'Abhijit V.', 'p...  2022
# 2      {'author': [{'ce:given-name': 'Solaphat', 'pre...  2022
# 3      {'author': [{'ce:given-name': 'Erik', 'preferr...  2022
# 4      {'author': [{'ce:given-name': 'Kunanya', 'pref...  2022
# ...                                                  ...   ...
# 20211  {'author': [{'ce:given-name': 'Panath', 'prefe...  2018
# 20212  {'author': [{'ce:given-name': 'Hiromi', 'prefe...  2018
# 20213  {'author': [{'ce:given-name': 'Sirinuch', 'pre...  2018
# 20214  {'author': [{'ce:given-name': 'Chutamas', 'pre...  2018
# 20215  {'author': [{'ce:given-name': 'Warn N.', 'pref...  2018
#
# [20216 rows x 9 columns]

# %%
data.restructure()

# %%
print(f"After restructure: {data.data.shape}")
# Out:
# After restructure: (20216, 8)

# %%
data.data
# Out:
#                                                  authors  year           id  \
# 0      Sureerat Thuekeaw, Kris Angkanaporn, Chackrit ...  2022  85131139456
# 1      Abhijit V. Lele, Sarah Wahlster, Bhunyawee Alu...  2022  85121351780
# 2      Solaphat Hemrungrojn, Arisara Amrapala, Michae...  2022  85131660961
# 3      Erik Johansson, Ferenc Tasnádi, Annop Ektarawo...  2022  85124670542
# 4            Kunanya Masodsai, Rungchai Chaunchaiyakul,   2022  85143878806
# ...                                                  ...   ...          ...
# 20211  Panath Jermthaisong, Sununtha Kingpaiboon, Pet...  2018  85063382127
# 20212  Hiromi Sawai, Nao Nishida, Seik-Soon Khor, Mas...  2018  85047370082
# 20213  Sirinuch Utarapichat, Wasuwat Kitisomprayoonkul,   2018  85042389729
# 20214  Chutamas Benjanirut, Chanakarn Wongsangchan, P...  2018  85055194236
# 20215  Warn N. Lekfuangfu, Nattavudh Powdthavee, Nele...  2018  85041549068
#
#                                                    title  \
# 0      Microencapsulated basil oil (Ocimum basilicum ...
# 1      Perceptions Regarding the SARS-CoV-2 Pandemic'...
# 2      Construction of a short version of the Montrea...
# 3      The effect of strain and pressure on the elect...
# 4      Dynamic Cardiopulmonary and Metabolic Function...
# ...                                                  ...
# 20211  Estimating actual evapotranspiration from NDVI...
# 20212  Genome-wide association study identified new s...
# 20213  Effects of transcranial direct current stimula...
# 20214  Prevalence and risk factors for canine cogniti...
# 20215  Locus of Control and its Intergenerational Imp...
#
#                                                 abstract  \
# 0      Objective: Microencapsulation is a technique t...
# 1      Background: The SARS-CoV-2 (COVID-19) pandemic...
# 2      Background: The Montreal Cognitive Assessment ...
# 3      Different theoretical methodologies are employ...
# 4      The purpose of this study was to investigate a...
# ...                                                  ...
# 20211  Evapotranspiration (ET) is the sum of evaporat...
# 20212  We have performed a genome-wide association st...
# 20213  Background: Anodal transcranial direct current...
# 20214  Canine cognitive dysfunction syndrome (CDS) is...
# 20215  This article builds upon Cunha's (2015) subjec...
#
#                                               references  \
# 0      [85039040394, 85050697915, 84920164411, 849664...
# 1      [85104589379, 85083241171, 85078262578, 850841...
# 2      [84982975791, 84871671961, 85097597113, 751491...
# 3      [0035282206, 0035508561, 0035858409, 183444013...
# 4      [25444452457, 49949090130, 84860884417, 848934...
# ...                                                  ...
# 20211  [0003491818, 79952741157, 0028978678, 00247710...
# 20212  [84947346338, 0033935745, 14944385553, 0035467...
# 20213  [33947494560, 33745243839, 36849022625, 751491...
# 20214  [59649128451, 0035379688, 84860848937, 8505515...
# 20215  [84917366795, 84958792377, 81155145322, 000186...
#
#                                                 category  source
# 0      [(Food Science, 1106, AGRI), (Physiology, 1314...  scopus
# 1      [(Surgery, 2746, MEDI), (Neurology (clinical),...  scopus
# 2                     [(Neuroscience (all), 2800, NEUR)]  scopus
# 3            [(Physics and Astronomy (all), 3100, PHYS)]  scopus
# 4                   [(Physiology (medical), 2737, MEDI)]  scopus
# ...                                                  ...     ...
# 20211            [(Artificial Intelligence, 1702, COMP)]  scopus
# 20212                  [(Multidisciplinary, 1000, MULT)]  scopus
# 20213                     [(Medicine (all), 2700, MEDI)]  scopus
# 20214                   [(Veterinary (all), 3400, VETE)]  scopus
# 20215         [(Economics and Econometrics, 2002, ECON)]  scopus
#
# [20216 rows x 8 columns]

# %%
data.data.sample(5)
# Out:
#                                                  authors  year           id  \
# 16844                              Suwanna Satha-Anand,   2020  85121090745
# 13562  Atchara Phumee, Supaporn Wacharapluesadee, Sin...  2021  85116357288
# 11709  Chayapol Tungphatthong, Santhosh Kumar J. Urum...  2021  85103347890
# 6646    Onsurang Wattanathamsan, Varisa Pongrakhananon,   2023  85117372713
# 13881  Siraphop Thapmongkol, Jarun Sayasathid, Jessad...  2021  85112770433
#
#                                                    title  \
# 16844  Caring detachment in buddhism and implications...
# 13562  Detection of Changuinola virus (Reoviridae: Or...
# 11709  Differentiation of Mitragyna speciosa, a narco...
# 6646   Post-translational modifications of tubulin: t...
# 13881  Growth of the pulmonary valve annulus after th...
#
#                                                 abstract  \
# 16844                                               None
# 13562  Background: Phlebotomine sand flies are vector...
# 11709  Mitragyna speciosa (Korth.) Havil. [MS], or “k...
# 6646   Microtubules play an important role in regulat...
# 13881  Background: The surgical outcomes of tetralogy...
#
#                                               references  \
# 16844  [33749608511, 84944723134, 84884054857, 000881...
# 13562  [84962467987, 85051020221, 85074108369, 850669...
# 11709  [85016137630, 34447134127, 85103357518, 002420...
# 6646   [0034743675, 85065562990, 0035667263, 85070377...
# 13881  [80855144819, 33645332975, 77956844737, 770492...
#
#                                                 category  source
# 16844  [(Arts and Humanities (all), 1200, ARTS), (Soc...  scopus
# 13562  [(Parasitology, 2405, IMMU), (Public Health, E...  scopus
# 11709                  [(Multidisciplinary, 1000, MULT)]  scopus
# 6646   [(Molecular Medicine, 1313, BIOC), (Molecular ...  scopus
# 13881  [(Pediatrics, Perinatology and Child Health, 2...  scopus

# %%
data.null_count()
# Out:
# Column authors have 0 null values
# Column year have 0 null values
# Column id have 0 null values
# Column title have 1 null values
# Column abstract have 665 null values
# Column references have 411 null values
# Column category have 0 null values
# Column source have 0 null values

# %%
data.data.dropna(subset=["abstract"], inplace=True)
data.data.dropna(subset=["references"], inplace=True)
data.data.dropna(subset=["title"], inplace=True)

data.data.shape
# Out:
# (19275, 8)

# %%
data.data
# Out:
#                                                  authors  year           id  \
# 0      Sureerat Thuekeaw, Kris Angkanaporn, Chackrit ...  2022  85131139456
# 1      Abhijit V. Lele, Sarah Wahlster, Bhunyawee Alu...  2022  85121351780
# 2      Solaphat Hemrungrojn, Arisara Amrapala, Michae...  2022  85131660961
# 3      Erik Johansson, Ferenc Tasnádi, Annop Ektarawo...  2022  85124670542
# 4            Kunanya Masodsai, Rungchai Chaunchaiyakul,   2022  85143878806
# ...                                                  ...   ...          ...
# 20211  Panath Jermthaisong, Sununtha Kingpaiboon, Pet...  2018  85063382127
# 20212  Hiromi Sawai, Nao Nishida, Seik-Soon Khor, Mas...  2018  85047370082
# 20213  Sirinuch Utarapichat, Wasuwat Kitisomprayoonkul,   2018  85042389729
# 20214  Chutamas Benjanirut, Chanakarn Wongsangchan, P...  2018  85055194236
# 20215  Warn N. Lekfuangfu, Nattavudh Powdthavee, Nele...  2018  85041549068
#
#                                                    title  \
# 0      Microencapsulated basil oil (Ocimum basilicum ...
# 1      Perceptions Regarding the SARS-CoV-2 Pandemic'...
# 2      Construction of a short version of the Montrea...
# 3      The effect of strain and pressure on the elect...
# 4      Dynamic Cardiopulmonary and Metabolic Function...
# ...                                                  ...
# 20211  Estimating actual evapotranspiration from NDVI...
# 20212  Genome-wide association study identified new s...
# 20213  Effects of transcranial direct current stimula...
# 20214  Prevalence and risk factors for canine cogniti...
# 20215  Locus of Control and its Intergenerational Imp...
#
#                                                 abstract  \
# 0      Objective: Microencapsulation is a technique t...
# 1      Background: The SARS-CoV-2 (COVID-19) pandemic...
# 2      Background: The Montreal Cognitive Assessment ...
# 3      Different theoretical methodologies are employ...
# 4      The purpose of this study was to investigate a...
# ...                                                  ...
# 20211  Evapotranspiration (ET) is the sum of evaporat...
# 20212  We have performed a genome-wide association st...
# 20213  Background: Anodal transcranial direct current...
# 20214  Canine cognitive dysfunction syndrome (CDS) is...
# 20215  This article builds upon Cunha's (2015) subjec...
#
#                                               references  \
# 0      [85039040394, 85050697915, 84920164411, 849664...
# 1      [85104589379, 85083241171, 85078262578, 850841...
# 2      [84982975791, 84871671961, 85097597113, 751491...
# 3      [0035282206, 0035508561, 0035858409, 183444013...
# 4      [25444452457, 49949090130, 84860884417, 848934...
# ...                                                  ...
# 20211  [0003491818, 79952741157, 0028978678, 00247710...
# 20212  [84947346338, 0033935745, 14944385553, 0035467...
# 20213  [33947494560, 33745243839, 36849022625, 751491...
# 20214  [59649128451, 0035379688, 84860848937, 8505515...
# 20215  [84917366795, 84958792377, 81155145322, 000186...
#
#                                                 category  source
# 0      [(Food Science, 1106, AGRI), (Physiology, 1314...  scopus
# 1      [(Surgery, 2746, MEDI), (Neurology (clinical),...  scopus
# 2                     [(Neuroscience (all), 2800, NEUR)]  scopus
# 3            [(Physics and Astronomy (all), 3100, PHYS)]  scopus
# 4                   [(Physiology (medical), 2737, MEDI)]  scopus
# ...                                                  ...     ...
# 20211            [(Artificial Intelligence, 1702, COMP)]  scopus
# 20212                  [(Multidisciplinary, 1000, MULT)]  scopus
# 20213                     [(Medicine (all), 2700, MEDI)]  scopus
# 20214                   [(Veterinary (all), 3400, VETE)]  scopus
# 20215         [(Economics and Econometrics, 2002, ECON)]  scopus
#
# [19275 rows x 8 columns]

# %%
data.save_data(file_name="scopus_unexplode_data.csv")
